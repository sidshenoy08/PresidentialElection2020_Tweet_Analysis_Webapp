# %%
import pandas as pd

# %% [markdown]
# # **Donald Trump Tweet Dataset**

# %%
trump_df = pd.read_csv('hashtag_donaldtrump.csv', lineterminator='\n')

# %% [markdown]
# Attributes in the dataset
#
# *   created_at: Date and time of tweet creation
# *   tweet_id: Unique ID of the tweet
#
#
# *   tweet: Full tweet text
# *   likes: Number of likes
#
# *   retweet_count: Number of retweets
# *   source: Utility used to post tweet
#
# *   user_id: User ID of tweet creator
# *   user_name: Username of tweet creator
#
# *   user_screen_name: Screen name of tweet creator
# *   user_description: Description of self by tweet creator
#
# *   user_join_date: Join date of tweet creator
# *   user_followers_count: Followers count on tweet creator
#
# *   user_location: Location given on tweet creator's profile
# *   lat: Latitude parsed from user_location
#
# *   long: Longitude parsed from user_location
# *   city: City parsed from user_location
#
# *   country: Country parsed from user_location
# *   state: State parsed from user_location
#
# *   state_code: State code parsed from user_location
# *   collected_at: Date and time tweet data was mined from twitter

# %% [markdown]
# Decompose into tweets, users, location

# %%
print(trump_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970919 entries, 0 to 970918
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            970919 non-null  object
#  1   tweet_id              970919 non-null  float64
#  2   tweet                 970919 non-null  object
#  3   likes                 970919 non-null  float64
#  4   retweet_count         970919 non-null  float64
#  5   source                970043 non-null  object
#  6   user_id               970919 non-null  float64
#  7   user_name             970897 non-null  object
#  8   user_screen_name      970919 non-null  object
#  9   user_description      869651 non-null  object
#  10  user_join_date        970919 non-null  object
#  11  user_followers_count  970919 non-null  float64
#  12  user_location         675957 non-null  object
#  13  lat                   445719 non-null  float64
#  14  long                  445719 non-null  float64
#  15  city                  227187 non-null  object
#  16  country               442748 non-null  object
#  17  continent             442765 non-null  object
#  18  state                 320620 non-null  object
#  19  state_code            300425 non-null  object
#  20  collected_at          970919 non-null  object
# dtypes: float64(7), object(14)
# memory usage: 155.6+ MB
# None

# %%
trump_df.head()
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:01  1.316529e+18
# 1  2020-10-15 00:00:01  1.316529e+18
# 2  2020-10-15 00:00:02  1.316529e+18
# 3  2020-10-15 00:00:02  1.316529e+18
# 4  2020-10-15 00:00:08  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  Usa 2020, Trump contro Facebook e Twitter: cop...   26.0            9.0
# 2  #Trump: As a student I used to hear for years,...    2.0            1.0
# 3  2 hours since last tweet from #Trump! Maybe he...    0.0            0.0
# 4  You get a tie! And you get a tie! #Trump ‘s ra...    4.0            3.0
#
#                source       user_id              user_name user_screen_name  \
# 0           TweetDeck  3.606665e+08     El Sol Latino News  elsollatinonews
# 1    Social Mediaset   3.316176e+08                Tgcom24  MediasetTgcom24
# 2     Twitter Web App  8.436472e+06                 snarke           snarke
# 3       Trumpytweeter  8.283556e+17          Trumpytweeter    trumpytweeter
# 4  Twitter for iPhone  4.741380e+07  Rana Abtar - رنا أبتر        Ranaabtar
#
#                                     user_description  ...  \
# 0  🌐 Noticias de interés para latinos de la costa...  ...
# 1  Profilo ufficiale di Tgcom24: tutte le notizie...  ...
# 2  Will mock for food! Freelance writer, blogger,...  ...
# 3  If he doesn't tweet for some time, should we b...  ...
# 4  Washington Correspondent, Lebanese-American ,c...  ...
#
#   user_followers_count                 user_location        lat        long  \
# 0               1860.0  Philadelphia, PA / Miami, FL  25.774270  -80.193660
# 1            1067661.0                           NaN        NaN         NaN
# 2               1185.0                      Portland  45.520247 -122.674195
# 3                 32.0                           NaN        NaN         NaN
# 4               5393.0                 Washington DC  38.894992  -77.036558
#
#          city                   country      continent                 state  \
# 0         NaN  United States of America  North America               Florida
# 1         NaN                       NaN            NaN                   NaN
# 2    Portland  United States of America  North America                Oregon
# 3         NaN                       NaN            NaN                   NaN
# 4  Washington  United States of America  North America  District of Columbia
#
#   state_code                   collected_at
# 0         FL            2020-10-21 00:00:00
# 1        NaN  2020-10-21 00:00:00.373216530
# 2         OR  2020-10-21 00:00:00.746433060
# 3        NaN  2020-10-21 00:00:01.119649591
# 4         DC  2020-10-21 00:00:01.492866121
#
# [5 rows x 21 columns]

# %%
trump_df['created_at'].sort_values()
# Out:
# 0         2020-10-15 00:00:01
# 1         2020-10-15 00:00:01
# 2         2020-10-15 00:00:02
# 3         2020-10-15 00:00:02
# 4         2020-10-15 00:00:08
#                  ...
# 970915    2020-11-08 23:59:48
# 970916    2020-11-08 23:59:53
# 970917    2020-11-08 23:59:54
# 970918    2020-11-08 23:59:55
# 922910    2020-11-08 23:59:56
# Name: created_at, Length: 970919, dtype: object

# %%
print(trump_df.groupby('country').first().loc[:,('tweet')])
# Out:
# country
# Afghanistan    ABig U Turn, #America was in war for a democra...
# Albania            @pdjmoo #trump didn't have #COVID19 #FakeNews
# Algeria        #Trump le candidat républicain tente de rectif...
# Angola         Como entender o debate entre #Trump e #Biden d...
# Anguilla       @funder .. Sen. #Perdue?, he's hiding under #T...
#                                      ...
# Venezuela      Barron Trump, de 14 años, hijo de #DonaldTrump...
# Vietnam        ⬇️Keep an eye on this in the days ahead...\n\n...
# Yemen          Stopping the aggression depends on the US, &am...
# Zambia         @45F0RLIFE @realDonaldTrump We can feel the #r...
# Zimbabwe                  #Trump pumpkin https://t.co/2fzrITjbDo
# Name: tweet, Length: 185, dtype: object

# %%
print(trump_df.country.unique())
# Out:
# ['United States of America' nan 'United Kingdom' 'Germany' 'United States'
#  'Australia' 'Costa Rica' 'Barbados' 'Cameroon' 'The Netherlands' 'Mexico'
#  'Canada' 'France' 'Peru' 'Argentina' 'South Korea' 'Finland' 'Mongolia'
#  'India' 'Japan' 'Turkey' 'Switzerland' 'Iran' 'Portugal' 'Ireland'
#  'Russia' 'Greece' 'Egypt' 'Ecuador' 'Colombia' 'Sri Lanka' 'Italy'
#  'China' 'Malaysia' 'Indonesia' 'Venezuela' 'Thailand' 'Sweden' 'Nepal'
#  'Bangladesh' 'Philippines' 'Dominican Republic' 'New Zealand' 'Chile'
#  'Honduras' 'Azerbaijan' 'Georgia' 'Spain' 'Cyprus' 'Morocco'
#  'Netherlands' 'Saudi Arabia' 'Norway' 'Singapore' 'Cuba' 'Niger'
#  'Hungary' 'Greenland' 'United Arab Emirates' 'Brazil' 'Uganda'
#  'Guatemala' 'Pakistan' 'Taiwan' 'Qatar' 'Afghanistan' 'South Africa'
#  'Nigeria' 'Slovakia' 'Guyana' 'Kenya' 'Iraq' 'Denmark' 'Uruguay'
#  'Belgium' 'Lebanon' 'Austria' 'Liechtenstein' 'Tunisia'
#  'Bosnia and Herzegovina' 'Iceland' 'Sudan' 'Czech Republic' 'Malta'
#  'Poland' 'Israel' 'Serbia' 'Luxembourg' 'Trinidad and Tobago' 'Ethiopia'
#  'Rwanda' 'Somalia' 'Panama' 'Ukraine' 'Kuwait' 'El Salvador'
#  'Palestinian Territory' 'Papua New Guinea' 'Nicaragua' 'Jersey' 'Bolivia'
#  'Bahrain' 'Cambodia' 'British Virgin Islands' 'Algeria' 'Uzbekistan'
#  'Kosovo' 'Albania' 'Myanmar' 'Monaco' 'Jamaika' 'Paraguay' 'Tanzania'
#  'Liberia' 'Cayman Islands' 'Gabon' 'Seychelles' 'Fiji' 'Laos' 'Maldives'
#  'Ghana' 'Mauritius' 'Gibraltar' 'Zimbabwe' 'Armenia' 'Latvia' 'Kiribati'
#  'Lithuania' 'Madagascar' 'The Gambia' 'Syria' 'Romania' 'Sierra Leone'
#  'Burkina Faso' 'Estonia' 'Jordan' 'Vietnam' 'Slovenia' 'Tajikistan'
#  "Côte d'Ivoire" 'Grenada' 'Republic of the Congo'
#  'Democratic Republic of the Congo' 'Senegal' 'Yemen' 'Croatia'
#  'Congo-Brazzaville' 'Libya' 'North Korea' 'Tonga' 'Oman' 'Moldova'
#  'Haiti' 'Angola' 'Djibouti' 'Falkland Islands' 'The Bahamas'
#  'Vatican City' 'Montenegro' 'Bulgaria' 'Zambia' 'Suriname'
#  'North Macedonia' 'Hong Kong' 'Guinea' 'Saint Kitts and Nevis' 'Bahamas'
#  'Puerto Rico' 'Dominica' 'Vanuatu' 'Namibia' 'Kazakhstan' 'Belize'
#  'Cape Verde' 'Benin' 'Northern Mariana Islands' 'Congo' 'Isle of Man'
#  'Turks and Caicos Islands' 'Anguilla' 'Belarus' 'South Sudan'
#  'Federated States of Micronesia' 'Faroe Islands' 'Antigua and Barbuda'
#  'Samoa']

# %%
print(trump_df.continent.unique())
# Out:
# ['North America' nan 'Europe' 'Oceania' 'Africa' 'South America' 'Asia'
#  'Antarctica']

# %%
trump_df.isnull().sum(axis=0)
# Out:
# created_at                   0
# tweet_id                     0
# tweet                        0
# likes                        0
# retweet_count                0
# source                     876
# user_id                      0
# user_name                   22
# user_screen_name             0
# user_description        101268
# user_join_date               0
# user_followers_count         0
# user_location           294962
# lat                     525200
# long                    525200
# city                    743732
# country                 528171
# continent               528154
# state                   650299
# state_code              670494
# collected_at                 0
# dtype: int64

# %%
print(trump_df.dtypes)
# Out:
# created_at               object
# tweet_id                float64
# tweet                    object
# likes                   float64
# retweet_count           float64
# source                   object
# user_id                 float64
# user_name                object
# user_screen_name         object
# user_description         object
# user_join_date           object
# user_followers_count    float64
# user_location            object
# lat                     float64
# long                    float64
# city                     object
# country                  object
# continent                object
# state                    object
# state_code               object
# collected_at             object
# dtype: object

# %%
print("Highest number of likes: {}".format(trump_df['likes'].max()))
print("Highest number of retweets: {}".format(trump_df['retweet_count'].max()))
print("Highest number of user followers: {}".format(trump_df['user_followers_count'].max()))
# Out:
# Highest number of likes: 74084.0
# Highest number of retweets: 20491.0
# Highest number of user followers: 19115332.0

# %%
print("For likes, Mean: {0:.3f} ".format(trump_df['likes'].mean()))
# Out:
# For likes, Mean: 7.477

# %%
trump_df.describe()
# Out:
#            tweet_id          likes  retweet_count       user_id  \
# count  9.709190e+05  970919.000000  970919.000000  9.709190e+05
# mean   1.322494e+18       7.477011       1.698500  4.468311e+17
# std    2.555133e+15     158.058117      40.028419  5.544702e+17
# min    1.316529e+18       0.000000       0.000000  5.310000e+02
# 25%    1.320478e+18       0.000000       0.000000  2.169326e+08
# 50%    1.323612e+18       0.000000       0.000000  2.373392e+09
# 75%    1.324505e+18       1.000000       0.000000  1.078344e+18
# max    1.325589e+18   74084.000000   20491.000000  1.325581e+18
#
#        user_followers_count            lat           long
# count          9.709190e+05  445719.000000  445719.000000
# mean           2.260357e+04      35.697936     -40.369638
# std            3.042152e+05      18.823129      67.531751
# min            0.000000e+00     -90.000000    -175.202642
# 25%            7.700000e+01      32.701939     -96.796856
# 50%            4.410000e+02      39.783730     -74.006015
# 75%            2.066000e+03      46.603354       6.776314
# max            1.911533e+07      90.000000     179.048837

# %%
trump_df['user_id'].nunique()
# Out:
# 301378

# %%
print(trump_df.groupby('user_id').first().loc[:, ('user_name', 'user_followers_count')].sort_values(by='user_followers_count', ascending=False))
# Out:
#                         user_name  user_followers_count
# user_id
# 3.388454e+07       CNN en Español            19108604.0
# 6.918316e+07             detikcom            16226346.0
# 3.703448e+07                 NDTV            13919823.0
# 1.115875e+09                 CGTN            13783686.0
# 1.347585e+08   The Times Of India            13205990.0
# ...                           ...                   ...
# 1.220208e+18                   ًً                   0.0
# 1.276604e+18  Reasonable Politics                   0.0
# 1.316290e+18              perucsm                   0.0
# 1.316291e+18           free money                   0.0
# 1.325581e+18      JoeBidenMilGrau                   0.0
#
# [301378 rows x 2 columns]

# %%
print(trump_df.groupby('country')['tweet_id'].count().sort_values(ascending=False))
# Out:
# country
# United States of America    178899
# United Kingdom               34743
# United States                34364
# Germany                      22618
# France                       20689
#                              ...
# Madagascar                       2
# Gabon                            1
# Antigua and Barbuda              1
# Samoa                            1
# Northern Mariana Islands         1
# Name: tweet_id, Length: 185, dtype: int64

# %%
trump_df.dropna(inplace=True)

# %%
trump_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189276 entries, 2 to 970907
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            189276 non-null  object
#  1   tweet_id              189276 non-null  float64
#  2   tweet                 189276 non-null  object
#  3   likes                 189276 non-null  float64
#  4   retweet_count         189276 non-null  float64
#  5   source                189276 non-null  object
#  6   user_id               189276 non-null  float64
#  7   user_name             189276 non-null  object
#  8   user_screen_name      189276 non-null  object
#  9   user_description      189276 non-null  object
#  10  user_join_date        189276 non-null  object
#  11  user_followers_count  189276 non-null  float64
#  12  user_location         189276 non-null  object
#  13  lat                   189276 non-null  float64
#  14  long                  189276 non-null  float64
#  15  city                  189276 non-null  object
#  16  country               189276 non-null  object
#  17  continent             189276 non-null  object
#  18  state                 189276 non-null  object
#  19  state_code            189276 non-null  object
#  20  collected_at          189276 non-null  object
# dtypes: float64(7), object(14)
# memory usage: 31.8+ MB

# %%
trump_df.isnull().sum(axis=0)
# Out:
# created_at              0
# tweet_id                0
# tweet                   0
# likes                   0
# retweet_count           0
# source                  0
# user_id                 0
# user_name               0
# user_screen_name        0
# user_description        0
# user_join_date          0
# user_followers_count    0
# user_location           0
# lat                     0
# long                    0
# city                    0
# country                 0
# continent               0
# state                   0
# state_code              0
# collected_at            0
# dtype: int64

# %%
print(trump_df.continent.unique())
# Out:
# ['North America' 'Europe' 'Oceania' 'Asia' 'South America' 'Africa']

# %%
print(trump_df.groupby('country')['tweet_id'].count().sort_values(ascending=False))
# Out:
# country
# United States of America    96622
# United Kingdom              18896
# Germany                     11457
# France                      11432
# Canada                      10239
# India                        9688
# Australia                    5149
# The Netherlands              4915
# Spain                        3040
# Brazil                       2148
# Pakistan                     1757
# Italy                        1725
# Bangladesh                   1372
# Ireland                      1183
# Belgium                      1114
# Nigeria                      1021
# Mexico                       1020
# South Africa                  954
# Switzerland                   880
# United Arab Emirates          736
# Peru                          594
# Lebanon                       490
# Ecuador                       465
# Argentina                     413
# Colombia                      306
# Honduras                      256
# Venezuela                     235
# New Zealand                   227
# Poland                        176
# Lithuania                     152
# Uruguay                       135
# Bolivia                       131
# El Salvador                    95
# Philippines                    45
# Oman                           41
# Trinidad and Tobago            35
# Papua New Guinea               34
# Syria                          15
# Sudan                          13
# Burkina Faso                   12
# Guatemala                      11
# Suriname                       10
# Côte d'Ivoire                  10
# Slovakia                        8
# Kuwait                          7
# Libya                           3
# South Sudan                     3
# Guyana                          2
# Laos                            2
# Cameroon                        1
# Somalia                         1
# Name: tweet_id, dtype: int64

# %%
print(trump_df.groupby('country')['retweet_count'].sum().sort_values(ascending=False))
# Out:
# country
# United States of America    309026.0
# France                       52945.0
# United Kingdom               44540.0
# Germany                      34046.0
# India                        18134.0
# Spain                        11657.0
# Canada                       10069.0
# Australia                     4456.0
# The Netherlands               3875.0
# Italy                         3116.0
# Switzerland                   2666.0
# Belgium                       2002.0
# Brazil                        1735.0
# Argentina                     1563.0
# United Arab Emirates          1556.0
# Pakistan                      1144.0
# Mexico                         948.0
# Ecuador                        913.0
# Peru                           803.0
# Lebanon                        770.0
# Nigeria                        682.0
# South Africa                   552.0
# Ireland                        405.0
# Poland                         376.0
# Colombia                       283.0
# Venezuela                      211.0
# Bangladesh                     209.0
# Uruguay                        194.0
# New Zealand                    118.0
# El Salvador                     81.0
# Honduras                        71.0
# Bolivia                         42.0
# Lithuania                       32.0
# Oman                            27.0
# Philippines                     26.0
# Syria                           13.0
# Laos                             9.0
# Côte d'Ivoire                    4.0
# Burkina Faso                     3.0
# Guatemala                        3.0
# Suriname                         2.0
# Cameroon                         1.0
# South Sudan                      1.0
# Slovakia                         1.0
# Papua New Guinea                 1.0
# Kuwait                           1.0
# Sudan                            0.0
# Somalia                          0.0
# Trinidad and Tobago              0.0
# Guyana                           0.0
# Libya                            0.0
# Name: retweet_count, dtype: float64

# %%
print(trump_df.groupby('user_name')['tweet_id'].count().sort_values(ascending=False))
# Out:
# user_name
# Revue2presse                   1352
# THCPetDoctor                    913
# Presidential News Network       709
# snarke                          566
# joshua epstein🏳️‍🌈🖖🏼🗽👨🏼‍💻🇺🇸     531
#                                ...
# Jonathan Denner                   1
# Jonathan Diaz😷                    1
# Jonathan Dromgoole                1
# Jonathan Dunne                    1
# 🩸Boost 🩸                          1
# Name: tweet_id, Length: 51663, dtype: int64

# %%
print(trump_df.city.unique())
# Out:
# ['Portland' 'Washington' 'Chicago' ... 'Deltona' 'Oviedo' 'Pocatello']

# %%
print(trump_df.loc[trump_df['country'] == 'India', 'state' ].unique())
# Out:
# ['Delhi' 'Maharashtra' 'Karnataka' 'Tamil Nadu' 'Gujarat' 'West Bengal'
#  'Andhra Pradesh' 'Uttar Pradesh' 'Rajasthan' 'Bihar' 'Assam' 'Odisha'
#  'Jammu and Kashmir' 'Madhya Pradesh' 'Haryana' 'Tripura' 'Kerala'
#  'Jharkhand' 'Punjab' 'Chhattisgarh' 'Uttarakhand' 'Telangana'
#  'Himachal Pradesh']

# %%
print(trump_df.loc[trump_df['country'] == 'United States of America', 'city' ].unique())
# Out:
# ['Portland' 'Washington' 'Chicago' 'San Diego' 'Tampa' 'Los Angeles'
#  'Lowell' 'Philadelphia' 'Houston' 'Grand Rapids' 'Kansas City' 'New York'
#  'Fitchburg' 'Denver' 'Jacksonville' 'Savannah' 'San Francisco'
#  'Cincinnati' 'Tallahassee' 'Arlington' 'Phoenix' 'Miami Beach' 'Raleigh'
#  'Miami' 'Nashville' 'Akron' 'Port St. Lucie' 'Carson City' 'Saint Paul'
#  'Cleveland' 'New Orleans' 'Reno' 'Atlanta' 'Boca Raton' 'Long Beach'
#  'Columbus' 'Kapolei' 'San Jose' 'Lansing' 'Boise' 'Memphis' 'Mansfield'
#  'Pensacola' 'Berkeley' 'Palm Harbor' 'Austin' 'Sarasota' 'Seattle'
#  'Inglewood' 'Fort Myers' 'Sacramento' 'Knoxville' 'Colorado Springs'
#  'Mobile' 'Hauppauge' 'Louisville' 'Des Moines' 'Detroit' 'Springfield'
#  'Tucson' 'El Paso' 'Cupertino' 'Boston' 'Minneapolis' 'Waterloo'
#  'Roanoke' 'Dallas' 'Vineland' 'Baltimore' 'St. Louis' 'Bethesda'
#  'Johnson City' 'Palo Alto' 'Palm Springs' 'Richmond' 'Albuquerque'
#  'Lubbock' 'Schenectady' 'Durham' 'Port Charlotte' 'Pittsburgh'
#  'San Rafael' 'Rochester' 'Las Vegas' 'Stockton' 'Orlando' 'Silver Spring'
#  'Helena' 'Baton Rouge' 'Tulsa' 'Anchorage' 'Thousand Oaks' 'Charlotte'
#  'West Palm Beach' 'Oakland' 'Santa Barbara' 'Clearwater' 'Clarksville'
#  'Albany' 'Kailua' 'Gastonia' 'Irvine' 'Bakersfield' 'Augusta'
#  'Oklahoma City' 'Greeley' 'Worcester' 'Lake Havasu City' 'Santa Clara'
#  'Fort Lauderdale' 'Honolulu' 'Frisco' 'Bremerton' 'Saint Petersburg'
#  'Longview' 'Ann Arbor' 'Santa Clarita' 'Lynchburg' 'Montgomery' 'Omaha'
#  'Traverse City' 'Salem' 'Sugar Land' 'Salt Lake City' 'Grand Junction'
#  'Kissimmee' 'Madison' 'Indianapolis' 'Santa Monica' 'Huntsville' 'Duluth'
#  'Burbank' 'Birmingham' 'Henderson' 'Kidder Township' 'Cambridge'
#  'Milwaukee' 'New Haven' 'Scottsdale' 'Wilmington' 'San Antonio'
#  'Dearborn' 'Spokane' 'Berlin' 'Buffalo' 'San Juan' 'Virginia Beach'
#  'Chico' 'Lakewood' 'Greenville' 'Pasadena' 'Santa Ana' 'Fairfield'
#  'Annapolis' 'Evansville' 'Palm Coast' 'Allentown' 'Beaverton' 'Asheville'
#  'Chattanooga' 'Fort Worth' 'Joliet' 'Boulder' 'Fayetteville' 'Tuscaloosa'
#  'Middle Township' 'Bozeman' 'Napa' 'Oceanside' 'Lower Yoder Township'
#  'Harrisburg' 'Newark' 'Mesa' 'Fresno' 'State College' 'Atlantic City'
#  'Yonkers' 'Riverside' 'Chula Vista' 'Topeka' 'Modesto' 'Erie'
#  'Boulder City' 'Bellevue' 'Delray Beach' 'Shreveport' 'Rio Rancho'
#  'Providence' 'Auburn' 'Corpus Christi' 'Fall River' 'Myrtle Beach'
#  'Petaluma' 'Bellingham' 'Vancouver' 'Abilene' 'Costa Mesa' 'Green Bay'
#  'Olympia' 'Peoria' 'Huntington Beach' 'Lancaster' 'Urbana' 'Youngstown'
#  'Mililani' 'Cape Coral' 'Cary' 'Rancho Cucamonga' 'Bradenton' 'Nashua'
#  'Temecula' 'Jonesboro' 'Logan Township' 'Lewiston' 'Dayton' 'Camden'
#  'Jefferson City' 'Garden City' 'Murrieta' 'Parkersburg' 'Lexington'
#  'Mountain View' 'Salina' 'Pueblo' 'Upper Macungie Township' 'Roswell'
#  'Boynton Beach' 'Laguna Beach' 'McAllen' 'Ocala' 'Jersey City'
#  'Santa Maria' 'Burlington' 'Gainesville' 'Flint' 'Tacoma' 'Oakdale'
#  'Eagle Pass' 'Frederick' 'Daytona Beach' 'Lake Charles' 'Prescott'
#  'Everett' 'Murfreesboro' 'Newport' 'El Cajon' 'Arvada' 'Charleston'
#  'York' 'Peabody' 'New Bedford' 'Spring Hill' 'Waco' 'Hartford'
#  'Toms River' 'Mesquite' 'Naperville' 'Pompano Beach' 'Newburyport'
#  'Texarkana' 'Grand Prairie' 'Amarillo' 'Toledo' 'Lower Macungie Township'
#  'Springdale' 'Anaheim' 'Davenport' 'Sheboygan' 'Wichita' 'Concord'
#  'North Las Vegas' 'Pomona' 'Hillsboro' 'Hagerstown' 'Kalamazoo' 'Lenoir'
#  'Euless' 'Wenatchee' 'Greensboro' 'Williamsburg' 'Plattsburgh' 'Provo'
#  'Rockford' 'Huron' 'Roseville' 'Little Rock' 'Peachtree City' 'Midland'
#  'Bangor' 'Sandy Springs' 'Rock Springs' 'Las Cruces' 'The Woodlands'
#  'Palmdale' 'Yuma' 'Binghamton' 'Dubuque' 'Paducah' 'Lawton'
#  'New Braunfels' 'Beaumont' 'Vacaville' 'Healdsburg' 'Harlingen'
#  'Fullerton' 'Dingman Township' 'Fontana' 'Essex' 'Towson' 'Muncie'
#  'Irving' 'Butte' 'Janesville' 'Chicopee' 'Jackson' 'Cedar Hill'
#  'Huntington' 'Glendale' 'Redding' 'Monterey' 'Palm Bay' 'Iowa City'
#  'Olathe' 'Chelsea' 'Odessa' 'Vallejo' 'Redwood City' 'Hialeah' 'Amesbury'
#  'Statesville' 'El Monte' 'Evanston' 'McKinney' 'Del Rio' 'Scranton'
#  'Bowling Green' 'Canton' 'Quincy' 'Altoona' 'Flagstaff' 'Athens'
#  'Morris Plains' 'Kenosha' 'Downey' 'Harrisonburg' 'Marietta' 'Sandy'
#  'Hayward' 'Kennewick' 'Elgin' 'Stamford' 'Weslaco' 'Laramie' 'Springtown'
#  'Hilo' 'Indio' 'Marlborough' 'Fargo' 'Biloxi' 'Largo'
#  'South Whitehall Township' 'Leominster' 'Kaneohe' 'Sunnyvale' 'Utica'
#  'Tempe' 'Syracuse' 'Columbia' 'Georgetown' 'Overland Park' 'New Castle'
#  'Suisun City' 'Scottsbluff' 'Plano' 'Grand Island' 'Cloverdale' 'Hanford'
#  'Manteca' 'Fremont' 'Newton' 'Torrance' 'Mission Viejo' 'Lakeland'
#  'Lower Providence Township' 'Hot Springs' 'Alexandria' 'Fairbanks'
#  'Cedar Rapids' 'Hickory' 'Valdosta' 'Independence' 'Manhattan'
#  'Dodge City' 'Brownsville' 'Pemberton' 'Thornton' 'Abington Township'
#  'Kailua-Kona' 'Battle Creek' 'North Augusta' 'Randolph Township'
#  'Spartanburg' 'Kingsport' 'Chesapeake' 'Joplin' 'Bloomington'
#  'Victorville' 'Mankato' 'South Bend' 'Norfolk' 'Lewisville' 'Westfield'
#  'Missoula' 'Fort Wayne' 'Canyon' 'Lower Southampton Township' 'Madera'
#  'Oxford' 'Bossier City' 'Racine' 'Wausau' 'Round Rock' 'Decatur' 'Tifton'
#  'New Brunswick' 'Macon' 'Pawtucket' 'Dothan' 'Mendham Township' 'Lehi'
#  'Hanover Township' 'Sparta' 'Turlock' 'Deerfield Beach' 'Killeen'
#  'Gulfport' 'Simi Valley' 'Ogden' 'Edinburg' 'Southaven' 'Trenton'
#  'Iowa Colony' 'Appleton' 'Casper' 'Concord Township' 'Kalispell' 'Gilroy'
#  'Sioux City' 'Yakima' 'Bridgeport' 'Framingham' 'La Crosse' 'Homestead'
#  'Laurel' 'Avondale' 'Laredo' 'Conyngham Township' 'Oxnard' 'Newburgh'
#  'Poway' 'Raymore' 'Salinas' 'Bensalem Township' 'Johns Creek' 'Escondido'
#  'Blue Springs' 'Ashland' 'Brandon' 'Ketchikan' 'Cape Girardeau'
#  'Cheyenne' 'Middletown' 'Salisbury' 'Winchester' 'Somerset' 'Warrensburg'
#  'Visalia' 'Bartlesville' 'Moline' 'Islip' 'North Charleston' 'Antioch'
#  'Lower Merion Township' 'St. Cloud' 'Paterson' 'Holyoke' 'Deltona'
#  'Pocatello']

# %%
print("For user_followers_count, Mean: {0}, Standard Deviation: {1}, Min: {2}, Max: {3}".format(trump_df['user_followers_count'].mean(), trump_df['user_followers_count'].std(), trump_df['user_followers_count'].min(), trump_df['user_followers_count'].max()))
# Out:
# For user_followers_count, Mean: 33785.141814070455, Standard Deviation: 271086.04080167064, Min: 0.0, Max: 13216027.0

# %%
trump_df.head()
# Out:
#              created_at      tweet_id  \
# 2   2020-10-15 00:00:02  1.316529e+18
# 4   2020-10-15 00:00:08  1.316529e+18
# 11  2020-10-15 00:00:25  1.316529e+18
# 12  2020-10-15 00:00:26  1.316529e+18
# 13  2020-10-15 00:00:31  1.316529e+18
#
#                                                 tweet  likes  retweet_count  \
# 2   #Trump: As a student I used to hear for years,...    2.0            1.0
# 4   You get a tie! And you get a tie! #Trump ‘s ra...    4.0            3.0
# 11  In 2020, #NYPost is being #censorship #CENSORE...    0.0            0.0
# 12  #Trump #PresidentTrump #Trump2020LandslideVict...    3.0            5.0
# 13  @Susan_Hutch @JoeBiden #Ukraine @RealDonaldTru...    2.0            0.0
#
#                  source       user_id  \
# 2       Twitter Web App  8.436472e+06
# 4    Twitter for iPhone  4.741380e+07
# 11   Twitter for iPhone  1.994033e+07
# 12  Twitter for Android  1.243315e+18
# 13      Twitter Web App  3.439562e+08
#
#                                             user_name user_screen_name  \
# 2                                              snarke           snarke
# 4                               Rana Abtar - رنا أبتر        Ranaabtar
# 11  Change Illinois | Biden will increase taxes by...   changeillinois
# 12                                       Ron Burgundy    Anchorman_USA
# 13                                    Sebastian White        SebWrites
#
#                                      user_description  ...  \
# 2   Will mock for food! Freelance writer, blogger,...  ...
# 4   Washington Correspondent, Lebanese-American ,c...  ...
# 11  Illinois, home of Lincoln and Reagan, used to ...  ...
# 12  I'm kind of a Big Deal, People know me! I driv...  ...
# 13  Tortured, literary genius, well probably the f...  ...
#
#    user_followers_count                   user_location        lat  \
# 2                1185.0                        Portland  45.520247
# 4                5393.0                   Washington DC  38.894992
# 11               1396.0               Chicago, Illinois  41.875562
# 12                496.0                   San Diego, CA  32.717421
# 13               2755.0  Edinburgh ~ Heart of Scotland!  55.953346
#
#           long               city                   country      continent  \
# 2  -122.674195           Portland  United States of America  North America
# 4   -77.036558         Washington  United States of America  North America
# 11  -87.624421            Chicago  United States of America  North America
# 12 -117.162771          San Diego  United States of America  North America
# 13   -3.188375  City of Edinburgh            United Kingdom         Europe
#
#                    state state_code                   collected_at
# 2                 Oregon         OR  2020-10-21 00:00:00.746433060
# 4   District of Columbia         DC  2020-10-21 00:00:01.492866121
# 11              Illinois         IL  2020-10-21 00:00:04.105381834
# 12            California         CA  2020-10-21 00:00:04.478598364
# 13              Scotland        SCT  2020-10-21 00:00:05.225031425
#
# [5 rows x 21 columns]

# %%
trump_users_df = trump_df[['user_id', 'user_name', 'user_screen_name', 'user_description', 'user_join_date', 'user_followers_count']]

# %%
trump_users_df.head()
# Out:
#          user_id                                          user_name  \
# 2   8.436472e+06                                             snarke
# 4   4.741380e+07                              Rana Abtar - رنا أبتر
# 11  1.994033e+07  Change Illinois | Biden will increase taxes by...
# 12  1.243315e+18                                       Ron Burgundy
# 13  3.439562e+08                                    Sebastian White
#
#    user_screen_name                                   user_description  \
# 2            snarke  Will mock for food! Freelance writer, blogger,...
# 4         Ranaabtar  Washington Correspondent, Lebanese-American ,c...
# 11   changeillinois  Illinois, home of Lincoln and Reagan, used to ...
# 12    Anchorman_USA  I'm kind of a Big Deal, People know me! I driv...
# 13        SebWrites  Tortured, literary genius, well probably the f...
#
#          user_join_date  user_followers_count
# 2   2007-08-26 05:56:11                1185.0
# 4   2009-06-15 19:05:35                5393.0
# 11  2009-02-02 23:08:28                1396.0
# 12  2020-03-26 23:14:28                 496.0
# 13  2011-07-28 10:07:32                2755.0

# %%
trump_users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189276 entries, 2 to 970907
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               189276 non-null  float64
#  1   user_name             189276 non-null  object
#  2   user_screen_name      189276 non-null  object
#  3   user_description      189276 non-null  object
#  4   user_join_date        189276 non-null  object
#  5   user_followers_count  189276 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 10.1+ MB

# %%
trump_users_df[trump_users_df.duplicated()]
# Out:
#              user_id                                    user_name  \
# 16      3.439562e+08                              Sebastian White
# 22      8.436472e+06                                       snarke
# 48      8.436472e+06                                       snarke
# 72      8.436472e+06                                       snarke
# 91      1.381774e+09                                          USA
# ...              ...                                          ...
# 970869  2.182470e+09  M.B.I. Munshi (MNZGamerX - Ace Level Troll)
# 970881  9.774065e+07                    Ian Sheltering in Oakland
# 970890  8.496398e+07                               Impacto Latino
# 970895  4.835231e+07       Linda "I Voted for Biden" Kenney Baden
# 970896  5.008862e+08                                   Ken Noble😎
#
#        user_screen_name                                   user_description  \
# 16            SebWrites  Tortured, literary genius, well probably the f...
# 22               snarke  Will mock for food! Freelance writer, blogger,...
# 48               snarke  Will mock for food! Freelance writer, blogger,...
# 72               snarke  Will mock for food! Freelance writer, blogger,...
# 91      AMERICANWILDMAN  I would rather die on my feet than live on my ...
# ...                 ...                                                ...
# 970869        MBIMunshi  Barrister & Advocate of the Supreme Court of B...
# 970881     IanWolfeRoss  people-first urbanist, founder @OppSites. I tw...
# 970890    ImpactoLatino  Últimas noticias de Nueva York, Estados Unidos...
# 970895      KenneyBaden  TrialLawyer https://t.co/1C0kKESSUC, Played by...
# 970896         knoble62  Believe in live & let live. Tweets are persona...
#
#              user_join_date  user_followers_count
# 16      2011-07-28 10:07:32                2755.0
# 22      2007-08-26 05:56:11                1185.0
# 48      2007-08-26 05:56:11                1185.0
# 72      2007-08-26 05:56:11                1185.0
# 91      2013-04-26 12:23:10                 110.0
# ...                     ...                   ...
# 970869  2013-11-08 15:59:05                1464.0
# 970881  2009-12-18 20:20:57                 425.0
# 970890  2009-10-24 23:36:28                1517.0
# 970895  2009-06-18 13:41:48                3024.0
# 970896  2012-02-23 15:31:47                 453.0
#
# [105568 rows x 6 columns]

# %%
trump_users_df['user_id'].nunique()
# Out:
# 52518

# %%
trump_locations_df = trump_df[['lat', 'long', 'city', 'state', 'state_code', 'country', 'continent']]

# %%
trump_locations_df.head()
# Out:
#           lat        long               city                 state state_code  \
# 2   45.520247 -122.674195           Portland                Oregon         OR
# 4   38.894992  -77.036558         Washington  District of Columbia         DC
# 11  41.875562  -87.624421            Chicago              Illinois         IL
# 12  32.717421 -117.162771          San Diego            California         CA
# 13  55.953346   -3.188375  City of Edinburgh              Scotland        SCT
#
#                      country      continent
# 2   United States of America  North America
# 4   United States of America  North America
# 11  United States of America  North America
# 12  United States of America  North America
# 13            United Kingdom         Europe

# %%
trump_locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189276 entries, 2 to 970907
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   lat         189276 non-null  float64
#  1   long        189276 non-null  float64
#  2   city        189276 non-null  object
#  3   state       189276 non-null  object
#  4   state_code  189276 non-null  object
#  5   country     189276 non-null  object
#  6   continent   189276 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 11.6+ MB

# %%
# drop state_code as it has no practical use
trump_locations_df.drop(['state_code'], axis=1, inplace=True)
# Out:
# <ipython-input-37-4fa5e1e062ce>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump_locations_df.drop(['state_code'], axis=1, inplace=True)

# %%
trump_locations_df[['lat', 'long']].nunique()
# Out:
# lat     1673
# long    1673
# dtype: int64

# %%
trump_tweets_df = trump_df[['tweet_id', 'tweet', 'likes', 'retweet_count', 'source', 'created_at', 'collected_at', 'user_id', 'user_location', 'lat', 'long']]

# %%
trump_tweets_df.loc[:, "tweet_about"] = "Trump"
# Out:
# <ipython-input-40-acb5a4ae94f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump_tweets_df.loc[:, "tweet_about"] = "Trump"

# %%
# drop user_location as lat and long are parsed from this field
trump_tweets_df.drop(['user_location'], axis=1, inplace=True)
# Out:
# <ipython-input-41-d12d15717b09>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump_tweets_df.drop(['user_location'], axis=1, inplace=True)

# %%
trump_tweets_df = trump_tweets_df[['tweet_id', 'tweet', 'likes', 'retweet_count', 'source', 'created_at', 'collected_at', 'tweet_about', 'user_id', 'lat', 'long']]

# %%
trump_tweets_df.head()
# Out:
#         tweet_id                                              tweet  likes  \
# 2   1.316529e+18  #Trump: As a student I used to hear for years,...    2.0
# 4   1.316529e+18  You get a tie! And you get a tie! #Trump ‘s ra...    4.0
# 11  1.316529e+18  In 2020, #NYPost is being #censorship #CENSORE...    0.0
# 12  1.316529e+18  #Trump #PresidentTrump #Trump2020LandslideVict...    3.0
# 13  1.316529e+18  @Susan_Hutch @JoeBiden #Ukraine @RealDonaldTru...    2.0
#
#     retweet_count               source           created_at  \
# 2             1.0      Twitter Web App  2020-10-15 00:00:02
# 4             3.0   Twitter for iPhone  2020-10-15 00:00:08
# 11            0.0   Twitter for iPhone  2020-10-15 00:00:25
# 12            5.0  Twitter for Android  2020-10-15 00:00:26
# 13            0.0      Twitter Web App  2020-10-15 00:00:31
#
#                      collected_at tweet_about       user_id        lat  \
# 2   2020-10-21 00:00:00.746433060       Trump  8.436472e+06  45.520247
# 4   2020-10-21 00:00:01.492866121       Trump  4.741380e+07  38.894992
# 11  2020-10-21 00:00:04.105381834       Trump  1.994033e+07  41.875562
# 12  2020-10-21 00:00:04.478598364       Trump  1.243315e+18  32.717421
# 13  2020-10-21 00:00:05.225031425       Trump  3.439562e+08  55.953346
#
#           long
# 2  -122.674195
# 4   -77.036558
# 11  -87.624421
# 12 -117.162771
# 13   -3.188375

# %%
trump_tweets_df['tweet_about'].unique()
# Out:
# array(['Trump'], dtype=object)

# %%
trump_tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189276 entries, 2 to 970907
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       189276 non-null  float64
#  1   tweet          189276 non-null  object
#  2   likes          189276 non-null  float64
#  3   retweet_count  189276 non-null  float64
#  4   source         189276 non-null  object
#  5   created_at     189276 non-null  object
#  6   collected_at   189276 non-null  object
#  7   tweet_about    189276 non-null  object
#  8   user_id        189276 non-null  float64
#  9   lat            189276 non-null  float64
#  10  long           189276 non-null  float64
# dtypes: float64(6), object(5)
# memory usage: 17.3+ MB

# %%
trump_tweets_df['tweet_id'].nunique()
# Out:
# 189093

# %% [markdown]
# # **Joe Biden Tweet Dataset**

# %%
biden_df = pd.read_csv('hashtag_joebiden.csv',lineterminator='\n')

# %%
biden_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776886 entries, 0 to 776885
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            776886 non-null  object
#  1   tweet_id              776886 non-null  float64
#  2   tweet                 776886 non-null  object
#  3   likes                 776886 non-null  float64
#  4   retweet_count         776886 non-null  float64
#  5   source                776173 non-null  object
#  6   user_id               776886 non-null  float64
#  7   user_name             776861 non-null  object
#  8   user_screen_name      776886 non-null  object
#  9   user_description      694877 non-null  object
#  10  user_join_date        776886 non-null  object
#  11  user_followers_count  776886 non-null  float64
#  12  user_location         543092 non-null  object
#  13  lat                   355293 non-null  float64
#  14  long                  355293 non-null  float64
#  15  city                  186872 non-null  object
#  16  country               353779 non-null  object
#  17  continent             353797 non-null  object
#  18  state                 260195 non-null  object
#  19  state_code            244609 non-null  object
#  20  collected_at          776886 non-null  object
# dtypes: float64(7), object(14)
# memory usage: 124.5+ MB

# %%
biden_df.describe()
# Out:
#            tweet_id          likes  retweet_count       user_id  \
# count  7.768860e+05  776886.000000  776886.000000  7.768860e+05
# mean   1.322844e+18      10.161164       2.131331  4.532033e+17
# std    2.585560e+15     390.974423      96.661527  5.573483e+17
# min    1.316529e+18       0.000000       0.000000  1.081000e+03
# 25%    1.320870e+18       0.000000       0.000000  2.257285e+08
# 50%    1.323899e+18       0.000000       0.000000  2.464208e+09
# 75%    1.325115e+18       2.000000       0.000000  1.088044e+18
# max    1.325589e+18  165702.000000   63473.000000  1.325575e+18
#
#        user_followers_count            lat           long
# count          7.768860e+05  355293.000000  355293.000000
# mean           2.884994e+04      35.104203     -41.979660
# std            4.141085e+05      17.907910      67.823724
# min            0.000000e+00     -79.406307    -172.120051
# 25%            7.400000e+01      31.816038     -97.268406
# 50%            4.280000e+02      39.783730     -74.006015
# 75%            2.081000e+03      43.653482       5.966069
# max            8.241710e+07      90.000000     179.048837

# %%
print("For user_followers_count, Mean: {0}, Standard Deviation: {1}, Min: {2}, Max: {3}".format(biden_df['user_followers_count'].mean(), biden_df['user_followers_count'].std(), biden_df['user_followers_count'].min(), biden_df['user_followers_count'].max()))
# Out:
# For user_followers_count, Mean: 28849.941210164685, Standard Deviation: 414108.478188055, Min: 0.0, Max: 82417099.0

# %%
biden_df.dropna(inplace=True)

# %%
biden_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155948 entries, 6 to 776876
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            155948 non-null  object
#  1   tweet_id              155948 non-null  float64
#  2   tweet                 155948 non-null  object
#  3   likes                 155948 non-null  float64
#  4   retweet_count         155948 non-null  float64
#  5   source                155948 non-null  object
#  6   user_id               155948 non-null  float64
#  7   user_name             155948 non-null  object
#  8   user_screen_name      155948 non-null  object
#  9   user_description      155948 non-null  object
#  10  user_join_date        155948 non-null  object
#  11  user_followers_count  155948 non-null  float64
#  12  user_location         155948 non-null  object
#  13  lat                   155948 non-null  float64
#  14  long                  155948 non-null  float64
#  15  city                  155948 non-null  object
#  16  country               155948 non-null  object
#  17  continent             155948 non-null  object
#  18  state                 155948 non-null  object
#  19  state_code            155948 non-null  object
#  20  collected_at          155948 non-null  object
# dtypes: float64(7), object(14)
# memory usage: 26.2+ MB

# %%
biden_df.isnull().sum(axis=0)
# Out:
# created_at              0
# tweet_id                0
# tweet                   0
# likes                   0
# retweet_count           0
# source                  0
# user_id                 0
# user_name               0
# user_screen_name        0
# user_description        0
# user_join_date          0
# user_followers_count    0
# user_location           0
# lat                     0
# long                    0
# city                    0
# country                 0
# continent               0
# state                   0
# state_code              0
# collected_at            0
# dtype: int64

# %%
biden_users_df = biden_df[['user_id', 'user_name', 'user_screen_name', 'user_description', 'user_join_date', 'user_followers_count']]

# %%
biden_users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155948 entries, 6 to 776876
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               155948 non-null  float64
#  1   user_name             155948 non-null  object
#  2   user_screen_name      155948 non-null  object
#  3   user_description      155948 non-null  object
#  4   user_join_date        155948 non-null  object
#  5   user_followers_count  155948 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 8.3+ MB

# %%
biden_users_df[biden_users_df.duplicated()]
# Out:
#              user_id                                    user_name  \
# 171     1.262894e+18                                  Grandma Lee
# 200     1.262894e+18                                  Grandma Lee
# 445     1.138467e+18                                    John Wait
# 509     8.682016e+07                                Russell Imrie
# 518     3.127945e+08                                         Jana
# ...              ...                                          ...
# 776836  1.057408e+09                                PROJECT13 MAG
# 776844  1.098900e+18                               andreh.cimoins
# 776852  1.588826e+07               Democracy Freedom Human Rights
# 776860  2.182470e+09  M.B.I. Munshi (MNZGamerX - Ace Level Troll)
# 776876  3.772296e+08                                    Tim Welch
#
#        user_screen_name                                   user_description  \
# 171     AliciaM05246586  My Grandchildren are brilliant, beautiful and ...
# 200     AliciaM05246586  My Grandchildren are brilliant, beautiful and ...
# 445     authorjohnselby  I am transitioning to a full-time writing care...
# 509          tweedyBard  takes on world & sec events UC NDN research an...
# 518      painwiseliving  Chronic Pain Education. Self-care/Resources\nF...
# ...                 ...                                                ...
# 776836     PROJECT13MAG  Sports | Motorsports | ET, Indie Film & Foodie...
# 776844          cimoins  ✨tatuador e ilustrador✨\n\ntattoo autoral | bl...
# 776852            biyer  Life is like a box of chocolates. You never kn...
# 776860        MBIMunshi  Barrister & Advocate of the Supreme Court of B...
# 776876        TimFWelch  transportation nerd; data geek.\nsenior lectur...
#
#              user_join_date  user_followers_count
# 171     2020-05-19 23:53:19                  42.0
# 200     2020-05-19 23:53:19                  42.0
# 445     2019-06-11 15:25:42                1383.0
# 509     2009-11-01 22:45:03                 133.0
# 518     2011-06-07 17:40:54                1538.0
# ...                     ...                   ...
# 776836  2013-01-03 10:12:09                8881.0
# 776844  2019-02-22 11:00:02                  52.0
# 776852  2008-08-18 03:40:48                  22.0
# 776860  2013-11-08 15:59:05                1464.0
# 776876  2011-09-21 07:13:23                 444.0
#
# [72001 rows x 6 columns]

# %%
biden_users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155948 entries, 6 to 776876
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               155948 non-null  float64
#  1   user_name             155948 non-null  object
#  2   user_screen_name      155948 non-null  object
#  3   user_description      155948 non-null  object
#  4   user_join_date        155948 non-null  object
#  5   user_followers_count  155948 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 8.3+ MB

# %%
biden_users_df['user_id'].nunique()
# Out:
# 58982

# %%
biden_locations_df = biden_df[['lat', 'long', 'city', 'state', 'state_code', 'country', 'continent']]

# %%
biden_locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155948 entries, 6 to 776876
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   lat         155948 non-null  float64
#  1   long        155948 non-null  float64
#  2   city        155948 non-null  object
#  3   state       155948 non-null  object
#  4   state_code  155948 non-null  object
#  5   country     155948 non-null  object
#  6   continent   155948 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 9.5+ MB

# %%
# drop state_code as it has no practical use
biden_locations_df.drop(['state_code'], axis=1, inplace=True)
# Out:
# <ipython-input-61-3149a234512d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biden_locations_df.drop(['state_code'], axis=1, inplace=True)

# %%
biden_locations_df[['lat', 'long']].nunique()
# Out:
# lat     1655
# long    1655
# dtype: int64

# %%
biden_tweets_df = biden_df[['tweet_id', 'tweet', 'likes', 'retweet_count', 'source', 'created_at', 'collected_at', 'user_id', 'user_location', 'lat', 'long']]

# %%
# drop user_location as lat and long are parsed from this field
biden_tweets_df.drop(['user_location'], axis=1, inplace=True)
# Out:
# <ipython-input-64-48e3b7843a94>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biden_tweets_df.drop(['user_location'], axis=1, inplace=True)

# %%
biden_tweets_df.loc[:, "tweet_about"] = "Biden"
# Out:
# <ipython-input-65-a45e7cac9545>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biden_tweets_df.loc[:, "tweet_about"] = "Biden"

# %%
biden_tweets_df = biden_tweets_df[['tweet_id', 'tweet', 'likes', 'retweet_count', 'source', 'created_at', 'collected_at', 'tweet_about', 'user_id', 'lat', 'long']]

# %%
biden_tweets_df.head()
# Out:
#         tweet_id                                              tweet  likes  \
# 6   1.316529e+18  In 2020, #NYPost is being #censorship #CENSORE...    0.0
# 17  1.316530e+18  Comments on this? "Do Democrats Understand how...    0.0
# 25  1.316530e+18  @RealJamesWoods #BidenCrimeFamily #JoeBiden #H...    0.0
# 28  1.316530e+18  #Trump #Obama #Clinton #Biden\n\n#ManWomanPers...    0.0
# 29  1.316530e+18  Come on @ABC PLEASE DO THE RIGHT THING. Move t...    0.0
#
#     retweet_count               source           created_at  \
# 6             0.0   Twitter for iPhone  2020-10-15 00:00:25
# 17            0.0      Twitter Web App  2020-10-15 00:01:23
# 25            0.0  Twitter for Android  2020-10-15 00:01:57
# 28            0.0   Twitter for iPhone  2020-10-15 00:02:05
# 29            0.0      Twitter Web App  2020-10-15 00:02:06
#
#                      collected_at tweet_about       user_id        lat  \
# 6   2020-10-21 00:00:03.106963698       Biden  1.994033e+07  41.875562
# 17  2020-10-21 00:00:08.803063811       Biden  1.016593e+08  27.947760
# 25  2020-10-21 00:00:12.945682075       Biden  1.300837e+18  34.053691
# 28  2020-10-21 00:00:14.499163924       Biden  1.321631e+08  51.507322
# 29  2020-10-21 00:00:15.016991207       Biden  3.343224e+08  40.712728
#
#           long
# 6   -87.624421
# 17  -82.458444
# 25 -118.242766
# 28   -0.127647
# 29  -74.006015

# %%
biden_tweets_df['tweet_about'].unique()
# Out:
# array(['Biden'], dtype=object)

# %%
biden_tweets_df['tweet_id'].nunique()
# Out:
# 155662

# %% [markdown]
# # **Combining the datasets**

# %%
trump_tweets_df['tweet_id'].nunique() + biden_tweets_df['tweet_id'].nunique()
# Out:
# 344755

# %%
tweets_df = pd.concat([trump_tweets_df, biden_tweets_df])

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 345224 entries, 2 to 776876
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       345224 non-null  float64
#  1   tweet          345224 non-null  object
#  2   likes          345224 non-null  float64
#  3   retweet_count  345224 non-null  float64
#  4   source         345224 non-null  object
#  5   created_at     345224 non-null  object
#  6   collected_at   345224 non-null  object
#  7   tweet_about    345224 non-null  object
#  8   user_id        345224 non-null  float64
#  9   lat            345224 non-null  float64
#  10  long           345224 non-null  float64
# dtypes: float64(6), object(5)
# memory usage: 31.6+ MB

# %%
tweets_df.head()
# Out:
#         tweet_id                                              tweet  likes  \
# 2   1.316529e+18  #Trump: As a student I used to hear for years,...    2.0
# 4   1.316529e+18  You get a tie! And you get a tie! #Trump ‘s ra...    4.0
# 11  1.316529e+18  In 2020, #NYPost is being #censorship #CENSORE...    0.0
# 12  1.316529e+18  #Trump #PresidentTrump #Trump2020LandslideVict...    3.0
# 13  1.316529e+18  @Susan_Hutch @JoeBiden #Ukraine @RealDonaldTru...    2.0
#
#     retweet_count               source           created_at  \
# 2             1.0      Twitter Web App  2020-10-15 00:00:02
# 4             3.0   Twitter for iPhone  2020-10-15 00:00:08
# 11            0.0   Twitter for iPhone  2020-10-15 00:00:25
# 12            5.0  Twitter for Android  2020-10-15 00:00:26
# 13            0.0      Twitter Web App  2020-10-15 00:00:31
#
#                      collected_at tweet_about       user_id        lat  \
# 2   2020-10-21 00:00:00.746433060       Trump  8.436472e+06  45.520247
# 4   2020-10-21 00:00:01.492866121       Trump  4.741380e+07  38.894992
# 11  2020-10-21 00:00:04.105381834       Trump  1.994033e+07  41.875562
# 12  2020-10-21 00:00:04.478598364       Trump  1.243315e+18  32.717421
# 13  2020-10-21 00:00:05.225031425       Trump  3.439562e+08  55.953346
#
#           long
# 2  -122.674195
# 4   -77.036558
# 11  -87.624421
# 12 -117.162771
# 13   -3.188375

# %%
tweets_df.tail()
# Out:
#             tweet_id                                              tweet  \
# 776860  1.325588e+18  @BreitbartNews Like all normal dictators &amp;...
# 776861  1.325588e+18  #election #2020Elections #trump #biden https:/...
# 776865  1.325589e+18  @FLOTUS I’m excited to have a FLOTUS whose vag...
# 776869  1.325589e+18  No puede ser lo #Panazis como siempre sacando ...
# 776876  1.325589e+18  Mr. #Biden, tear down that wall (with #Mexico)...
#
#         likes  retweet_count              source           created_at  \
# 776860    0.0            0.0     Twitter Web App  2020-11-08 23:58:02
# 776861    0.0            0.0  Twitter for iPhone  2020-11-08 23:58:09
# 776865    0.0            0.0  Twitter for iPhone  2020-11-08 23:58:24
# 776869    0.0            0.0  Twitter for iPhone  2020-11-08 23:58:46
# 776876    1.0            0.0  Twitter for iPhone  2020-11-08 23:59:16
#
#                       collected_at tweet_about       user_id        lat  \
# 776860  2020-11-09 18:32:45.622677       Biden  2.182470e+09  23.810651
# 776861  2020-11-09 18:32:45.608982       Biden  9.538012e+17  40.712728
# 776865  2020-11-09 18:32:45.841439       Biden  5.545625e+07  38.894992
# 776869  2020-11-09 18:32:45.862885       Biden  7.406354e+17  32.501019
# 776876  2020-11-09 18:32:45.760347       Biden  3.772296e+08 -36.852095
#
#               long
# 776860   90.412647
# 776861  -74.006015
# 776865  -77.036558
# 776869 -116.964663
# 776876  174.763180

# %%
# shuffle the merged dataframe
tweets_df = tweets_df.sample(frac=1)

# %%
tweets_df.head()
# Out:
#             tweet_id                                              tweet  \
# 276625  1.322929e+18  US politicians are fire-and-forget weapons: On...
# 247473  1.320554e+18  Remember when the @GOP said #ObamaCare was goi...
# 483553  1.323603e+18  ट्रम्प यांच्या विजयासाठी हिंदू सेनेतर्फे मंदिर...
# 211909  1.319852e+18  If India's Air is filthy then you are Dust Par...
# 355463  1.322271e+18  Extraordinary the American woman who can't see...
#
#         likes  retweet_count               source           created_at  \
# 276625    5.0            1.0      Twitter Web App  2020-11-01 15:51:51
# 247473    1.0            0.0   Twitter for iPhone  2020-10-26 02:33:01
# 483553    3.0            0.0      Twitter Web App  2020-11-03 12:27:45
# 211909    4.0            0.0  Twitter for Android  2020-10-24 04:02:48
# 355463    2.0            0.0      Twitter Web App  2020-10-30 20:17:32
#
#                       collected_at tweet_about      user_id        lat  \
# 276625  2020-11-02 16:18:25.437596       Biden  137379679.0  32.717421
# 247473  2020-10-27 17:37:58.659980       Trump  262802030.0  37.974764
# 483553  2020-11-04 10:49:38.912230       Trump  491986148.0  19.075990
# 211909  2020-10-27 18:35:23.856307       Trump   58401024.0  26.916194
# 355463  2020-11-01 10:56:29.707345       Trump  443554155.0  51.507322
#
#               long
# 276625 -117.162771
# 247473  -87.555848
# 483553   72.877393
# 211909   75.820349
# 355463   -0.127647

# %%
# convert ids to integer notation
tweets_df[['tweet_id', 'likes', 'retweet_count', 'user_id']] = tweets_df[['tweet_id', 'likes', 'retweet_count', 'user_id']].astype(int)

# %%
tweets_df.head()
# Out:
#                    tweet_id  \
# 276625  1322929354142175232
# 247473  1320553992141836288
# 483553  1323602766527229952
# 211909  1319851811516248064
# 355463  1322271438305374208
#
#                                                     tweet  likes  \
# 276625  US politicians are fire-and-forget weapons: On...      5
# 247473  Remember when the @GOP said #ObamaCare was goi...      1
# 483553  ट्रम्प यांच्या विजयासाठी हिंदू सेनेतर्फे मंदिर...      3
# 211909  If India's Air is filthy then you are Dust Par...      4
# 355463  Extraordinary the American woman who can't see...      2
#
#         retweet_count               source           created_at  \
# 276625              1      Twitter Web App  2020-11-01 15:51:51
# 247473              0   Twitter for iPhone  2020-10-26 02:33:01
# 483553              0      Twitter Web App  2020-11-03 12:27:45
# 211909              0  Twitter for Android  2020-10-24 04:02:48
# 355463              0      Twitter Web App  2020-10-30 20:17:32
#
#                       collected_at tweet_about    user_id        lat  \
# 276625  2020-11-02 16:18:25.437596       Biden  137379679  32.717421
# 247473  2020-10-27 17:37:58.659980       Trump  262802030  37.974764
# 483553  2020-11-04 10:49:38.912230       Trump  491986148  19.075990
# 211909  2020-10-27 18:35:23.856307       Trump   58401024  26.916194
# 355463  2020-11-01 10:56:29.707345       Trump  443554155  51.507322
#
#               long
# 276625 -117.162771
# 247473  -87.555848
# 483553   72.877393
# 211909   75.820349
# 355463   -0.127647

# %%
tweets_df['tweet_id'].nunique()
# Out:
# 299384

# %%
# drop rows having duplicate tweet_ids to enforce Primary Key constraint in tweets relation
tweets_df.drop_duplicates(subset=['tweet_id'], inplace=True)

# %%
print(tweets_df['tweet_id'].max())
print(tweets_df['user_id'].max())
print(tweets_df['tweet'].str.len().max())
# Out:
# 1325588768448000000
# 1325568705393274880
# 976

# %%
tweets_df['source'].str.len().max()
# Out:
# 32

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299384 entries, 276625 to 80046
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       299384 non-null  int64
#  1   tweet          299384 non-null  object
#  2   likes          299384 non-null  int64
#  3   retweet_count  299384 non-null  int64
#  4   source         299384 non-null  object
#  5   created_at     299384 non-null  object
#  6   collected_at   299384 non-null  object
#  7   tweet_about    299384 non-null  object
#  8   user_id        299384 non-null  int64
#  9   lat            299384 non-null  float64
#  10  long           299384 non-null  float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 27.4+ MB

# %%
users_df = pd.concat([trump_users_df, biden_users_df])

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 345224 entries, 2 to 776876
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               345224 non-null  float64
#  1   user_name             345224 non-null  object
#  2   user_screen_name      345224 non-null  object
#  3   user_description      345224 non-null  object
#  4   user_join_date        345224 non-null  object
#  5   user_followers_count  345224 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 18.4+ MB

# %%
users_df['user_id'].nunique()
# Out:
# 86807

# %%
# drop rows having duplicate user_ids to enforce Primary Key constraint in tweets relation
users_df.drop_duplicates(subset=['user_id'], inplace=True)

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86807 entries, 2 to 776869
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               86807 non-null  float64
#  1   user_name             86807 non-null  object
#  2   user_screen_name      86807 non-null  object
#  3   user_description      86807 non-null  object
#  4   user_join_date        86807 non-null  object
#  5   user_followers_count  86807 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 4.6+ MB

# %%
users_df.head()
# Out:
#          user_id                                          user_name  \
# 2   8.436472e+06                                             snarke
# 4   4.741380e+07                              Rana Abtar - رنا أبتر
# 11  1.994033e+07  Change Illinois | Biden will increase taxes by...
# 12  1.243315e+18                                       Ron Burgundy
# 13  3.439562e+08                                    Sebastian White
#
#    user_screen_name                                   user_description  \
# 2            snarke  Will mock for food! Freelance writer, blogger,...
# 4         Ranaabtar  Washington Correspondent, Lebanese-American ,c...
# 11   changeillinois  Illinois, home of Lincoln and Reagan, used to ...
# 12    Anchorman_USA  I'm kind of a Big Deal, People know me! I driv...
# 13        SebWrites  Tortured, literary genius, well probably the f...
#
#          user_join_date  user_followers_count
# 2   2007-08-26 05:56:11                1185.0
# 4   2009-06-15 19:05:35                5393.0
# 11  2009-02-02 23:08:28                1396.0
# 12  2020-03-26 23:14:28                 496.0
# 13  2011-07-28 10:07:32                2755.0

# %%
users_df[['user_id', 'user_followers_count']] = users_df[['user_id', 'user_followers_count']].astype(int)

# %%
print(users_df['user_name'].str.len().max())
print(users_df['user_screen_name'].str.len().max())
print(users_df['user_description'].str.len().max())
# Out:
# 50
# 15
# 225

# %%
users_df.head()
# Out:
#                 user_id                                          user_name  \
# 2               8436472                                             snarke
# 4              47413798                              Rana Abtar - رنا أبتر
# 11             19940334  Change Illinois | Biden will increase taxes by...
# 12  1243315346397966336                                       Ron Burgundy
# 13            343956175                                    Sebastian White
#
#    user_screen_name                                   user_description  \
# 2            snarke  Will mock for food! Freelance writer, blogger,...
# 4         Ranaabtar  Washington Correspondent, Lebanese-American ,c...
# 11   changeillinois  Illinois, home of Lincoln and Reagan, used to ...
# 12    Anchorman_USA  I'm kind of a Big Deal, People know me! I driv...
# 13        SebWrites  Tortured, literary genius, well probably the f...
#
#          user_join_date  user_followers_count
# 2   2007-08-26 05:56:11                  1185
# 4   2009-06-15 19:05:35                  5393
# 11  2009-02-02 23:08:28                  1396
# 12  2020-03-26 23:14:28                   496
# 13  2011-07-28 10:07:32                  2755

# %%
locations_df = pd.concat([trump_locations_df, biden_locations_df])

# %%
locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 345224 entries, 2 to 776876
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        345224 non-null  float64
#  1   long       345224 non-null  float64
#  2   city       345224 non-null  object
#  3   state      345224 non-null  object
#  4   country    345224 non-null  object
#  5   continent  345224 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 18.4+ MB

# %%
locations_df[['lat', 'long']].nunique()
# Out:
# lat     1911
# long    1911
# dtype: int64

# %%
# drop rows having duplicate (lat, long) to enforce Primary Key constraint in tweets relation
locations_df.drop_duplicates(subset=['lat', 'long'], inplace=True)

# %%
print(locations_df['city'].str.len().max())
print(locations_df['state'].str.len().max())
print(locations_df['country'].str.len().max())
print(locations_df['continent'].str.len().max())
# Out:
# 40
# 42
# 24
# 13

# %%
locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1911 entries, 2 to 772205
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        1911 non-null   float64
#  1   long       1911 non-null   float64
#  2   city       1911 non-null   object
#  3   state      1911 non-null   object
#  4   country    1911 non-null   object
#  5   continent  1911 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 104.5+ KB

# %%
locations_df.head()
# Out:
#           lat        long               city                 state  \
# 2   45.520247 -122.674195           Portland                Oregon
# 4   38.894992  -77.036558         Washington  District of Columbia
# 11  41.875562  -87.624421            Chicago              Illinois
# 12  32.717421 -117.162771          San Diego            California
# 13  55.953346   -3.188375  City of Edinburgh              Scotland
#
#                      country      continent
# 2   United States of America  North America
# 4   United States of America  North America
# 11  United States of America  North America
# 12  United States of America  North America
# 13            United Kingdom         Europe

# %% [markdown]
# # **Final Relations**

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299384 entries, 276625 to 80046
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       299384 non-null  int64
#  1   tweet          299384 non-null  object
#  2   likes          299384 non-null  int64
#  3   retweet_count  299384 non-null  int64
#  4   source         299384 non-null  object
#  5   created_at     299384 non-null  object
#  6   collected_at   299384 non-null  object
#  7   tweet_about    299384 non-null  object
#  8   user_id        299384 non-null  int64
#  9   lat            299384 non-null  float64
#  10  long           299384 non-null  float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 27.4+ MB

# %%
tweets_df.head()
# Out:
#                    tweet_id  \
# 276625  1322929354142175232
# 247473  1320553992141836288
# 483553  1323602766527229952
# 211909  1319851811516248064
# 355463  1322271438305374208
#
#                                                     tweet  likes  \
# 276625  US politicians are fire-and-forget weapons: On...      5
# 247473  Remember when the @GOP said #ObamaCare was goi...      1
# 483553  ट्रम्प यांच्या विजयासाठी हिंदू सेनेतर्फे मंदिर...      3
# 211909  If India's Air is filthy then you are Dust Par...      4
# 355463  Extraordinary the American woman who can't see...      2
#
#         retweet_count               source           created_at  \
# 276625              1      Twitter Web App  2020-11-01 15:51:51
# 247473              0   Twitter for iPhone  2020-10-26 02:33:01
# 483553              0      Twitter Web App  2020-11-03 12:27:45
# 211909              0  Twitter for Android  2020-10-24 04:02:48
# 355463              0      Twitter Web App  2020-10-30 20:17:32
#
#                       collected_at tweet_about    user_id        lat  \
# 276625  2020-11-02 16:18:25.437596       Biden  137379679  32.717421
# 247473  2020-10-27 17:37:58.659980       Trump  262802030  37.974764
# 483553  2020-11-04 10:49:38.912230       Trump  491986148  19.075990
# 211909  2020-10-27 18:35:23.856307       Trump   58401024  26.916194
# 355463  2020-11-01 10:56:29.707345       Trump  443554155  51.507322
#
#               long
# 276625 -117.162771
# 247473  -87.555848
# 483553   72.877393
# 211909   75.820349
# 355463   -0.127647

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86807 entries, 2 to 776869
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               86807 non-null  int64
#  1   user_name             86807 non-null  object
#  2   user_screen_name      86807 non-null  object
#  3   user_description      86807 non-null  object
#  4   user_join_date        86807 non-null  object
#  5   user_followers_count  86807 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 6.7+ MB

# %%
users_df.head()
# Out:
#                 user_id                                          user_name  \
# 2               8436472                                             snarke
# 4              47413798                              Rana Abtar - رنا أبتر
# 11             19940334  Change Illinois | Biden will increase taxes by...
# 12  1243315346397966336                                       Ron Burgundy
# 13            343956175                                    Sebastian White
#
#    user_screen_name                                   user_description  \
# 2            snarke  Will mock for food! Freelance writer, blogger,...
# 4         Ranaabtar  Washington Correspondent, Lebanese-American ,c...
# 11   changeillinois  Illinois, home of Lincoln and Reagan, used to ...
# 12    Anchorman_USA  I'm kind of a Big Deal, People know me! I driv...
# 13        SebWrites  Tortured, literary genius, well probably the f...
#
#          user_join_date  user_followers_count
# 2   2007-08-26 05:56:11                  1185
# 4   2009-06-15 19:05:35                  5393
# 11  2009-02-02 23:08:28                  1396
# 12  2020-03-26 23:14:28                   496
# 13  2011-07-28 10:07:32                  2755

# %%
locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1911 entries, 2 to 772205
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        1911 non-null   float64
#  1   long       1911 non-null   float64
#  2   city       1911 non-null   object
#  3   state      1911 non-null   object
#  4   country    1911 non-null   object
#  5   continent  1911 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 104.5+ KB

# %%
locations_df.head()
# Out:
#           lat        long               city                 state  \
# 2   45.520247 -122.674195           Portland                Oregon
# 4   38.894992  -77.036558         Washington  District of Columbia
# 11  41.875562  -87.624421            Chicago              Illinois
# 12  32.717421 -117.162771          San Diego            California
# 13  55.953346   -3.188375  City of Edinburgh              Scotland
#
#                      country      continent
# 2   United States of America  North America
# 4   United States of America  North America
# 11  United States of America  North America
# 12  United States of America  North America
# 13            United Kingdom         Europe

# %% [markdown]
# # **Exporting the relations**

# %%
tweets_df.to_csv('tweets.csv', index=False)

# %%
users_df.to_csv('users.csv', index=False)

# %%
locations_df.to_csv('locations.csv', index=False)
