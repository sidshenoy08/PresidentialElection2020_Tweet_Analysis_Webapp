# %%
import pandas as pd

# %% [markdown]
# # **Donald Trump Tweet Dataset**

# %%
trump_df = pd.read_csv('hashtag_donaldtrump.csv', lineterminator='\n')

# %% [markdown]
# Attributes in the dataset
#
# *   created_at: Date and time of tweet creation
# *   tweet_id: Unique ID of the tweet
#
#
# *   tweet: Full tweet text
# *   likes: Number of likes
#
# *   retweet_count: Number of retweets
# *   source: Utility used to post tweet
#
# *   user_id: User ID of tweet creator
# *   user_name: Username of tweet creator
#
# *   user_screen_name: Screen name of tweet creator
# *   user_description: Description of self by tweet creator
#
# *   user_join_date: Join date of tweet creator
# *   user_followers_count: Followers count on tweet creator
#
# *   user_location: Location given on tweet creator's profile
# *   lat: Latitude parsed from user_location
#
# *   long: Longitude parsed from user_location
# *   city: City parsed from user_location
#
# *   country: Country parsed from user_location
# *   state: State parsed from user_location
#
# *   state_code: State code parsed from user_location
# *   collected_at: Date and time tweet data was mined from twitter

# %% [markdown]
# Decompose into tweets, users, location

# %%
print(trump_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970919 entries, 0 to 970918
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            970919 non-null  object
#  1   tweet_id              970919 non-null  float64
#  2   tweet                 970919 non-null  object
#  3   likes                 970919 non-null  float64
#  4   retweet_count         970919 non-null  float64
#  5   source                970043 non-null  object
#  6   user_id               970919 non-null  float64
#  7   user_name             970897 non-null  object
#  8   user_screen_name      970919 non-null  object
#  9   user_description      869651 non-null  object
#  10  user_join_date        970919 non-null  object
#  11  user_followers_count  970919 non-null  float64
#  12  user_location         675957 non-null  object
#  13  lat                   445719 non-null  float64
#  14  long                  445719 non-null  float64
#  15  city                  227187 non-null  object
#  16  country               442748 non-null  object
#  17  continent             442765 non-null  object
#  18  state                 320620 non-null  object
#  19  state_code            300425 non-null  object
#  20  collected_at          970919 non-null  object
# dtypes: float64(7), object(14)
# memory usage: 155.6+ MB
# None

# %%
trump_df.head()
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:01  1.316529e+18
# 1  2020-10-15 00:00:01  1.316529e+18
# 2  2020-10-15 00:00:02  1.316529e+18
# 3  2020-10-15 00:00:02  1.316529e+18
# 4  2020-10-15 00:00:08  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  Usa 2020, Trump contro Facebook e Twitter: cop...   26.0            9.0
# 2  #Trump: As a student I used to hear for years,...    2.0            1.0
# 3  2 hours since last tweet from #Trump! Maybe he...    0.0            0.0
# 4  You get a tie! And you get a tie! #Trump ‘s ra...    4.0            3.0
#
#                source       user_id              user_name user_screen_name  \
# 0           TweetDeck  3.606665e+08     El Sol Latino News  elsollatinonews
# 1    Social Mediaset   3.316176e+08                Tgcom24  MediasetTgcom24
# 2     Twitter Web App  8.436472e+06                 snarke           snarke
# 3       Trumpytweeter  8.283556e+17          Trumpytweeter    trumpytweeter
# 4  Twitter for iPhone  4.741380e+07  Rana Abtar - رنا أبتر        Ranaabtar
#
#                                     user_description  ...  \
# 0  🌐 Noticias de interés para latinos de la costa...  ...
# 1  Profilo ufficiale di Tgcom24: tutte le notizie...  ...
# 2  Will mock for food! Freelance writer, blogger,...  ...
# 3  If he doesn't tweet for some time, should we b...  ...
# 4  Washington Correspondent, Lebanese-American ,c...  ...
#
#   user_followers_count                 user_location        lat        long  \
# 0               1860.0  Philadelphia, PA / Miami, FL  25.774270  -80.193660
# 1            1067661.0                           NaN        NaN         NaN
# 2               1185.0                      Portland  45.520247 -122.674195
# 3                 32.0                           NaN        NaN         NaN
# 4               5393.0                 Washington DC  38.894992  -77.036558
#
#          city                   country      continent                 state  \
# 0         NaN  United States of America  North America               Florida
# 1         NaN                       NaN            NaN                   NaN
# 2    Portland  United States of America  North America                Oregon
# 3         NaN                       NaN            NaN                   NaN
# 4  Washington  United States of America  North America  District of Columbia
#
#   state_code                   collected_at
# 0         FL            2020-10-21 00:00:00
# 1        NaN  2020-10-21 00:00:00.373216530
# 2         OR  2020-10-21 00:00:00.746433060
# 3        NaN  2020-10-21 00:00:01.119649591
# 4         DC  2020-10-21 00:00:01.492866121
#
# [5 rows x 21 columns]

# %%
trump_df['created_at'].sort_values()
# Out:
# 0         2020-10-15 00:00:01
# 1         2020-10-15 00:00:01
# 2         2020-10-15 00:00:02
# 3         2020-10-15 00:00:02
# 4         2020-10-15 00:00:08
#                  ...
# 970915    2020-11-08 23:59:48
# 970916    2020-11-08 23:59:53
# 970917    2020-11-08 23:59:54
# 970918    2020-11-08 23:59:55
# 922910    2020-11-08 23:59:56
# Name: created_at, Length: 970919, dtype: object

# %%
print(trump_df.groupby('country').first().loc[:,('tweet')])
# Out:
# country
# Afghanistan    ABig U Turn, #America was in war for a democra...
# Albania            @pdjmoo #trump didn't have #COVID19 #FakeNews
# Algeria        #Trump le candidat républicain tente de rectif...
# Angola         Como entender o debate entre #Trump e #Biden d...
# Anguilla       @funder .. Sen. #Perdue?, he's hiding under #T...
#                                      ...
# Venezuela      Barron Trump, de 14 años, hijo de #DonaldTrump...
# Vietnam        ⬇️Keep an eye on this in the days ahead...\n\n...
# Yemen          Stopping the aggression depends on the US, &am...
# Zambia         @45F0RLIFE @realDonaldTrump We can feel the #r...
# Zimbabwe                  #Trump pumpkin https://t.co/2fzrITjbDo
# Name: tweet, Length: 185, dtype: object

# %%
print(trump_df.country.unique())
# Out:
# ['United States of America' nan 'United Kingdom' 'Germany' 'United States'
#  'Australia' 'Costa Rica' 'Barbados' 'Cameroon' 'The Netherlands' 'Mexico'
#  'Canada' 'France' 'Peru' 'Argentina' 'South Korea' 'Finland' 'Mongolia'
#  'India' 'Japan' 'Turkey' 'Switzerland' 'Iran' 'Portugal' 'Ireland'
#  'Russia' 'Greece' 'Egypt' 'Ecuador' 'Colombia' 'Sri Lanka' 'Italy'
#  'China' 'Malaysia' 'Indonesia' 'Venezuela' 'Thailand' 'Sweden' 'Nepal'
#  'Bangladesh' 'Philippines' 'Dominican Republic' 'New Zealand' 'Chile'
#  'Honduras' 'Azerbaijan' 'Georgia' 'Spain' 'Cyprus' 'Morocco'
#  'Netherlands' 'Saudi Arabia' 'Norway' 'Singapore' 'Cuba' 'Niger'
#  'Hungary' 'Greenland' 'United Arab Emirates' 'Brazil' 'Uganda'
#  'Guatemala' 'Pakistan' 'Taiwan' 'Qatar' 'Afghanistan' 'South Africa'
#  'Nigeria' 'Slovakia' 'Guyana' 'Kenya' 'Iraq' 'Denmark' 'Uruguay'
#  'Belgium' 'Lebanon' 'Austria' 'Liechtenstein' 'Tunisia'
#  'Bosnia and Herzegovina' 'Iceland' 'Sudan' 'Czech Republic' 'Malta'
#  'Poland' 'Israel' 'Serbia' 'Luxembourg' 'Trinidad and Tobago' 'Ethiopia'
#  'Rwanda' 'Somalia' 'Panama' 'Ukraine' 'Kuwait' 'El Salvador'
#  'Palestinian Territory' 'Papua New Guinea' 'Nicaragua' 'Jersey' 'Bolivia'
#  'Bahrain' 'Cambodia' 'British Virgin Islands' 'Algeria' 'Uzbekistan'
#  'Kosovo' 'Albania' 'Myanmar' 'Monaco' 'Jamaika' 'Paraguay' 'Tanzania'
#  'Liberia' 'Cayman Islands' 'Gabon' 'Seychelles' 'Fiji' 'Laos' 'Maldives'
#  'Ghana' 'Mauritius' 'Gibraltar' 'Zimbabwe' 'Armenia' 'Latvia' 'Kiribati'
#  'Lithuania' 'Madagascar' 'The Gambia' 'Syria' 'Romania' 'Sierra Leone'
#  'Burkina Faso' 'Estonia' 'Jordan' 'Vietnam' 'Slovenia' 'Tajikistan'
#  "Côte d'Ivoire" 'Grenada' 'Republic of the Congo'
#  'Democratic Republic of the Congo' 'Senegal' 'Yemen' 'Croatia'
#  'Congo-Brazzaville' 'Libya' 'North Korea' 'Tonga' 'Oman' 'Moldova'
#  'Haiti' 'Angola' 'Djibouti' 'Falkland Islands' 'The Bahamas'
#  'Vatican City' 'Montenegro' 'Bulgaria' 'Zambia' 'Suriname'
#  'North Macedonia' 'Hong Kong' 'Guinea' 'Saint Kitts and Nevis' 'Bahamas'
#  'Puerto Rico' 'Dominica' 'Vanuatu' 'Namibia' 'Kazakhstan' 'Belize'
#  'Cape Verde' 'Benin' 'Northern Mariana Islands' 'Congo' 'Isle of Man'
#  'Turks and Caicos Islands' 'Anguilla' 'Belarus' 'South Sudan'
#  'Federated States of Micronesia' 'Faroe Islands' 'Antigua and Barbuda'
#  'Samoa']

# %%
print(trump_df.continent.unique())
# Out:
# ['North America' nan 'Europe' 'Oceania' 'Africa' 'South America' 'Asia'
#  'Antarctica']

# %%
trump_df.isnull().sum(axis=0)
# Out:
# created_at                   0
# tweet_id                     0
# tweet                        0
# likes                        0
# retweet_count                0
# source                     876
# user_id                      0
# user_name                   22
# user_screen_name             0
# user_description        101268
# user_join_date               0
# user_followers_count         0
# user_location           294962
# lat                     525200
# long                    525200
# city                    743732
# country                 528171
# continent               528154
# state                   650299
# state_code              670494
# collected_at                 0
# dtype: int64

# %%
print(trump_df.dtypes)
# Out:
# created_at               object
# tweet_id                float64
# tweet                    object
# likes                   float64
# retweet_count           float64
# source                   object
# user_id                 float64
# user_name                object
# user_screen_name         object
# user_description         object
# user_join_date           object
# user_followers_count    float64
# user_location            object
# lat                     float64
# long                    float64
# city                     object
# country                  object
# continent                object
# state                    object
# state_code               object
# collected_at             object
# dtype: object

# %%
print("Highest number of likes: {}".format(trump_df['likes'].max()))
print("Highest number of retweets: {}".format(trump_df['retweet_count'].max()))
print("Highest number of user followers: {}".format(trump_df['user_followers_count'].max()))
# Out:
# Highest number of likes: 74084.0
# Highest number of retweets: 20491.0
# Highest number of user followers: 19115332.0

# %%
print("For likes, Mean: {0:.3f} ".format(trump_df['likes'].mean()))
# Out:
# For likes, Mean: 7.477

# %%
trump_df.describe()
# Out:
#            tweet_id          likes  retweet_count       user_id  \
# count  9.709190e+05  970919.000000  970919.000000  9.709190e+05
# mean   1.322494e+18       7.477011       1.698500  4.468311e+17
# std    2.555133e+15     158.058117      40.028419  5.544702e+17
# min    1.316529e+18       0.000000       0.000000  5.310000e+02
# 25%    1.320478e+18       0.000000       0.000000  2.169326e+08
# 50%    1.323612e+18       0.000000       0.000000  2.373392e+09
# 75%    1.324505e+18       1.000000       0.000000  1.078344e+18
# max    1.325589e+18   74084.000000   20491.000000  1.325581e+18
#
#        user_followers_count            lat           long
# count          9.709190e+05  445719.000000  445719.000000
# mean           2.260357e+04      35.697936     -40.369638
# std            3.042152e+05      18.823129      67.531751
# min            0.000000e+00     -90.000000    -175.202642
# 25%            7.700000e+01      32.701939     -96.796856
# 50%            4.410000e+02      39.783730     -74.006015
# 75%            2.066000e+03      46.603354       6.776314
# max            1.911533e+07      90.000000     179.048837

# %%
trump_df['user_id'].nunique()
# Out:
# 301378

# %%
print(trump_df.groupby('user_id').first().loc[:, ('user_name', 'user_followers_count')].sort_values(by='user_followers_count', ascending=False))
# Out:
#                         user_name  user_followers_count
# user_id
# 3.388454e+07       CNN en Español            19108604.0
# 6.918316e+07             detikcom            16226346.0
# 3.703448e+07                 NDTV            13919823.0
# 1.115875e+09                 CGTN            13783686.0
# 1.347585e+08   The Times Of India            13205990.0
# ...                           ...                   ...
# 1.220208e+18                   ًً                   0.0
# 1.276604e+18  Reasonable Politics                   0.0
# 1.316290e+18              perucsm                   0.0
# 1.316291e+18           free money                   0.0
# 1.325581e+18      JoeBidenMilGrau                   0.0
#
# [301378 rows x 2 columns]

# %%
print(trump_df.groupby('country')['tweet_id'].count().sort_values(ascending=False))
# Out:
# country
# United States of America    178899
# United Kingdom               34743
# United States                34364
# Germany                      22618
# France                       20689
#                              ...
# Madagascar                       2
# Gabon                            1
# Antigua and Barbuda              1
# Samoa                            1
# Northern Mariana Islands         1
# Name: tweet_id, Length: 185, dtype: int64

# %%
trump_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970919 entries, 0 to 970918
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            970919 non-null  object
#  1   tweet_id              970919 non-null  float64
#  2   tweet                 970919 non-null  object
#  3   likes                 970919 non-null  float64
#  4   retweet_count         970919 non-null  float64
#  5   source                970043 non-null  object
#  6   user_id               970919 non-null  float64
#  7   user_name             970897 non-null  object
#  8   user_screen_name      970919 non-null  object
#  9   user_description      869651 non-null  object
#  10  user_join_date        970919 non-null  object
#  11  user_followers_count  970919 non-null  float64
#  12  user_location         675957 non-null  object
#  13  lat                   445719 non-null  float64
#  14  long                  445719 non-null  float64
#  15  city                  227187 non-null  object
#  16  country               442748 non-null  object
#  17  continent             442765 non-null  object
#  18  state                 320620 non-null  object
#  19  state_code            300425 non-null  object
#  20  collected_at          970919 non-null  object
# dtypes: float64(7), object(14)
# memory usage: 155.6+ MB

# %%
# drop irrelevant columns
trump_df.drop(['state_code', 'user_location'], axis=1, inplace=True)

# %%
# replace null descriptions with a static string
trump_df['user_description'].fillna("No user description", inplace=True)
# Out:
# <ipython-input-47-9de98956faec>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   trump_df['user_description'].fillna("No user description", inplace=True)

# %%
# replace null usernames with user screen names
trump_df['user_name'].fillna(trump_df['user_screen_name'], inplace=True)
# Out:
# <ipython-input-50-605d86558b37>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   trump_df['user_name'].fillna(trump_df['user_screen_name'], inplace=True)

# %%
# replace null source values using the ffill method
trump_df['source'].fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-52-b6bb5f3769bd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   trump_df['source'].fillna(method='ffill', inplace=True)
# <ipython-input-52-b6bb5f3769bd>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   trump_df['source'].fillna(method='ffill', inplace=True)

# %%
trump_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970919 entries, 0 to 970918
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            970919 non-null  object
#  1   tweet_id              970919 non-null  float64
#  2   tweet                 970919 non-null  object
#  3   likes                 970919 non-null  float64
#  4   retweet_count         970919 non-null  float64
#  5   source                970919 non-null  object
#  6   user_id               970919 non-null  float64
#  7   user_name             970919 non-null  object
#  8   user_screen_name      970919 non-null  object
#  9   user_description      970919 non-null  object
#  10  user_join_date        970919 non-null  object
#  11  user_followers_count  970919 non-null  float64
#  12  lat                   445719 non-null  float64
#  13  long                  445719 non-null  float64
#  14  city                  227187 non-null  object
#  15  country               442748 non-null  object
#  16  continent             442765 non-null  object
#  17  state                 320620 non-null  object
#  18  collected_at          970919 non-null  object
# dtypes: float64(7), object(12)
# memory usage: 140.7+ MB

# %%
trump_df.dropna(subset=['lat', 'long', 'city', 'country', 'continent', 'state'], inplace=True)

# %%
trump_df.head()
# Out:
#              created_at      tweet_id  \
# 2   2020-10-15 00:00:02  1.316529e+18
# 4   2020-10-15 00:00:08  1.316529e+18
# 11  2020-10-15 00:00:25  1.316529e+18
# 12  2020-10-15 00:00:26  1.316529e+18
# 13  2020-10-15 00:00:31  1.316529e+18
#
#                                                 tweet  likes  retweet_count  \
# 2   #Trump: As a student I used to hear for years,...    2.0            1.0
# 4   You get a tie! And you get a tie! #Trump ‘s ra...    4.0            3.0
# 11  In 2020, #NYPost is being #censorship #CENSORE...    0.0            0.0
# 12  #Trump #PresidentTrump #Trump2020LandslideVict...    3.0            5.0
# 13  @Susan_Hutch @JoeBiden #Ukraine @RealDonaldTru...    2.0            0.0
#
#                  source       user_id  \
# 2       Twitter Web App  8.436472e+06
# 4    Twitter for iPhone  4.741380e+07
# 11   Twitter for iPhone  1.994033e+07
# 12  Twitter for Android  1.243315e+18
# 13      Twitter Web App  3.439562e+08
#
#                                             user_name user_screen_name  \
# 2                                              snarke           snarke
# 4                               Rana Abtar - رنا أبتر        Ranaabtar
# 11  Change Illinois | Biden will increase taxes by...   changeillinois
# 12                                       Ron Burgundy    Anchorman_USA
# 13                                    Sebastian White        SebWrites
#
#                                      user_description       user_join_date  \
# 2   Will mock for food! Freelance writer, blogger,...  2007-08-26 05:56:11
# 4   Washington Correspondent, Lebanese-American ,c...  2009-06-15 19:05:35
# 11  Illinois, home of Lincoln and Reagan, used to ...  2009-02-02 23:08:28
# 12  I'm kind of a Big Deal, People know me! I driv...  2020-03-26 23:14:28
# 13  Tortured, literary genius, well probably the f...  2011-07-28 10:07:32
#
#     user_followers_count        lat        long               city  \
# 2                 1185.0  45.520247 -122.674195           Portland
# 4                 5393.0  38.894992  -77.036558         Washington
# 11                1396.0  41.875562  -87.624421            Chicago
# 12                 496.0  32.717421 -117.162771          San Diego
# 13                2755.0  55.953346   -3.188375  City of Edinburgh
#
#                      country      continent                 state  \
# 2   United States of America  North America                Oregon
# 4   United States of America  North America  District of Columbia
# 11  United States of America  North America              Illinois
# 12  United States of America  North America            California
# 13            United Kingdom         Europe              Scotland
#
#                      collected_at
# 2   2020-10-21 00:00:00.746433060
# 4   2020-10-21 00:00:01.492866121
# 11  2020-10-21 00:00:04.105381834
# 12  2020-10-21 00:00:04.478598364
# 13  2020-10-21 00:00:05.225031425

# %%
trump_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 213309 entries, 2 to 970912
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            213309 non-null  object
#  1   tweet_id              213309 non-null  float64
#  2   tweet                 213309 non-null  object
#  3   likes                 213309 non-null  float64
#  4   retweet_count         213309 non-null  float64
#  5   source                213309 non-null  object
#  6   user_id               213309 non-null  float64
#  7   user_name             213309 non-null  object
#  8   user_screen_name      213309 non-null  object
#  9   user_description      213309 non-null  object
#  10  user_join_date        213309 non-null  object
#  11  user_followers_count  213309 non-null  float64
#  12  lat                   213309 non-null  float64
#  13  long                  213309 non-null  float64
#  14  city                  213309 non-null  object
#  15  country               213309 non-null  object
#  16  continent             213309 non-null  object
#  17  state                 213309 non-null  object
#  18  collected_at          213309 non-null  object
# dtypes: float64(7), object(12)
# memory usage: 32.5+ MB

# %%
trump_df.isnull().sum(axis=0)
# Out:
# created_at              0
# tweet_id                0
# tweet                   0
# likes                   0
# retweet_count           0
# source                  0
# user_id                 0
# user_name               0
# user_screen_name        0
# user_description        0
# user_join_date          0
# user_followers_count    0
# lat                     0
# long                    0
# city                    0
# country                 0
# continent               0
# state                   0
# collected_at            0
# dtype: int64

# %%
print(trump_df.continent.unique())
# Out:
# ['North America' 'Europe' 'Oceania' 'Asia' 'South America' 'Africa']

# %%
print(trump_df.groupby('country')['tweet_id'].count().sort_values(ascending=False))
# Out:
# country
# United States of America    101967
# United Kingdom               20031
# Germany                      12371
# France                       11920
# Canada                       10809
#                              ...
# Paraguay                         1
# Somalia                          1
# Madagascar                       1
# Cameroon                         1
# Palestinian Territory            1
# Name: tweet_id, Length: 100, dtype: int64

# %%
print(trump_df.groupby('country')['retweet_count'].sum().sort_values(ascending=False))
# Out:
# country
# United States of America    310122.0
# France                       53152.0
# United Kingdom               44810.0
# Germany                      34275.0
# India                        18197.0
#                               ...
# Libya                            0.0
# Madagascar                       0.0
# Malaysia                         0.0
# Myanmar                          0.0
# Guyana                           0.0
# Name: retweet_count, Length: 100, dtype: float64

# %%
print(trump_df.groupby('user_name')['tweet_id'].count().sort_values(ascending=False))
# Out:
# user_name
# Revue2presse                   1352
# THCPetDoctor                    913
# Presidential News Network       709
# snarke                          566
# joshua epstein🏳️‍🌈🖖🏼🗽👨🏼‍💻🇺🇸     531
#                                ...
# Jordan Juarez                     1
# Jordan L. LaGrâce🇨🇲🇩🇪             1
# Jordan Lau                        1
# Jordan Levin                      1
# 🩸Boost 🩸                          1
# Name: tweet_id, Length: 60837, dtype: int64

# %%
print(trump_df.city.unique())
# Out:
# ['Portland' 'Washington' 'Chicago' ... 'Oviedo' 'Chengdu City' 'Pocatello']

# %%
print(trump_df.loc[trump_df['country'] == 'India', 'state' ].unique())
# Out:
# ['Delhi' 'Maharashtra' 'Karnataka' 'Tamil Nadu' 'Gujarat' 'West Bengal'
#  'Andhra Pradesh' 'Uttar Pradesh' 'Rajasthan' 'Bihar' 'Assam' 'Odisha'
#  'Jammu and Kashmir' 'Madhya Pradesh' 'Haryana' 'Tripura' 'Kerala'
#  'Jharkhand' 'Punjab' 'Chhattisgarh' 'Uttarakhand' 'Telangana'
#  'Himachal Pradesh']

# %%
print(trump_df.loc[trump_df['country'] == 'United States of America', 'city' ].unique())
# Out:
# ['Portland' 'Washington' 'Chicago' 'San Diego' 'Tampa' 'Los Angeles'
#  'Lowell' 'Philadelphia' 'Houston' 'Grand Rapids' 'Kansas City' 'New York'
#  'Fitchburg' 'Denver' 'Jacksonville' 'Savannah' 'San Francisco'
#  'Cincinnati' 'Tallahassee' 'Arlington' 'Phoenix' 'Miami Beach' 'Raleigh'
#  'Miami' 'Nashville' 'Akron' 'Port St. Lucie' 'Carson City' 'Saint Paul'
#  'Cleveland' 'New Orleans' 'Reno' 'Indianapolis' 'Atlanta' 'McKinney'
#  'Boca Raton' 'Long Beach' 'Schenectady' 'Columbus' 'Kapolei' 'San Jose'
#  'Lansing' 'Boise' 'Memphis' 'Mansfield' 'Pensacola' 'Berkeley'
#  'Palm Harbor' 'Austin' 'Sarasota' 'St. Louis' 'Seattle' 'Inglewood'
#  'Fort Myers' 'Sacramento' 'Knoxville' 'Colorado Springs' 'Mobile'
#  'Hauppauge' 'Louisville' 'Des Moines' 'Detroit' 'Springfield' 'Tucson'
#  'El Paso' 'Cupertino' 'Boston' 'Minneapolis' 'Waterloo' 'Roanoke'
#  'Dallas' 'Vineland' 'Baltimore' 'Bethesda' 'Johnson City' 'Palo Alto'
#  'Palm Springs' 'Richmond' 'Albuquerque' 'Lubbock' 'Durham'
#  'Port Charlotte' 'Pittsburgh' 'San Rafael' 'Rochester' 'Las Vegas'
#  'Rancho Cucamonga' 'Fresno' 'Stockton' 'Orlando' 'Silver Spring' 'Helena'
#  'Baton Rouge' 'Tulsa' 'Anchorage' 'Thousand Oaks' 'Charlotte'
#  'West Palm Beach' 'Oakland' 'Santa Barbara' 'Clearwater' 'Clarksville'
#  'Albany' 'Worcester' 'Kailua' 'Gastonia' 'Irvine' 'Bakersfield' 'Augusta'
#  'Oklahoma City' 'Greeley' 'Lake Havasu City' 'Santa Clara'
#  'Fort Lauderdale' 'Honolulu' 'Frisco' 'Bremerton' 'Saint Petersburg'
#  'Longview' 'Ann Arbor' 'Santa Clarita' 'Lynchburg' 'Yuma' 'Montgomery'
#  'Omaha' 'Traverse City' 'Salem' 'Sugar Land' 'Salt Lake City'
#  'Grand Junction' 'Kissimmee' 'Madison' 'Santa Monica' 'Huntsville'
#  'Duluth' 'Burbank' 'Birmingham' 'Henderson' 'Kidder Township' 'Cambridge'
#  'Milwaukee' 'New Haven' 'Scottsdale' 'Wilmington' 'San Antonio'
#  'Dearborn' 'Spokane' 'Berlin' 'Buffalo' 'San Juan' 'Virginia Beach'
#  'Camden' 'Chico' 'Lakewood' 'Greenville' 'Pasadena' 'Santa Ana'
#  'Fairfield' 'Dayton' 'Annapolis' 'Evansville' 'Palm Coast' 'Allentown'
#  'Beaverton' 'Asheville' 'Jersey City' 'Chattanooga' 'Fort Worth' 'Joliet'
#  'Boulder' 'Fayetteville' 'Tuscaloosa' 'Middle Township' 'Bozeman' 'Napa'
#  'Oceanside' 'Lower Yoder Township' 'Harrisburg' 'Newark' 'Mesa' 'McAllen'
#  'State College' 'Atlantic City' 'Yonkers' 'Lancaster' 'Riverside'
#  'Chula Vista' 'Topeka' 'Modesto' 'Erie' 'Boulder City' 'Bellevue'
#  'Delray Beach' 'Shreveport' 'Rio Rancho' 'Providence' 'Auburn'
#  'Corpus Christi' 'Fall River' 'Myrtle Beach' 'Petaluma' 'Bellingham'
#  'Waldron' 'Vancouver' 'Abilene' 'Costa Mesa' 'Green Bay' 'Olympia'
#  'Peoria' 'Huntington Beach' 'Urbana' 'Youngstown' 'Mililani' 'Gary'
#  'Cape Coral' 'Cary' 'Bradenton' 'Nashua' 'Temecula' 'Jonesboro'
#  'Logan Township' 'Lewiston' 'Jefferson City' 'Garden City' 'Murrieta'
#  'Parkersburg' 'Lexington' 'Mountain View' 'Salina' 'Pueblo'
#  'Upper Macungie Township' 'Roswell' 'Boynton Beach' 'Laguna Beach'
#  'Randolph Township' 'Ocala' 'Santa Maria' 'Burlington' 'Gainesville'
#  'Flint' 'Tacoma' 'Oakdale' 'Eagle Pass' 'Frederick' 'Daytona Beach'
#  'Lake Charles' 'Prescott' 'Everett' 'Murfreesboro' 'Newport' 'El Cajon'
#  'Arvada' 'Middletown' 'Charleston' 'York' 'Peabody' 'New Bedford'
#  'Spring Hill' 'Waco' 'Hartford' 'Toms River' 'Mesquite' 'Naperville'
#  'Pompano Beach' 'Newburyport' 'Texarkana' 'Grand Prairie' 'Amarillo'
#  'Toledo' 'Lower Macungie Township' 'Springdale' 'Anaheim' 'Davenport'
#  'Sheboygan' 'Wichita' 'Bloomington' 'Concord' 'North Las Vegas' 'Pomona'
#  'Spartanburg' 'Hillsboro' 'Hagerstown' 'Kalamazoo' 'Lenoir' 'Euless'
#  'Wenatchee' 'Greensboro' 'Williamsburg' 'Plattsburgh' 'Provo' 'Rockford'
#  'Huron' 'Roseville' 'Little Rock' 'Peachtree City' 'Midland' 'Bangor'
#  'Sandy Springs' 'Rock Springs' 'Las Cruces' 'The Woodlands' 'Waterbury'
#  'Palmdale' 'Binghamton' 'Dubuque' 'Paducah' 'Lawton' 'Trenton'
#  'New Braunfels' 'Beaumont' 'Vacaville' 'Healdsburg' 'Jackson' 'Harlingen'
#  'Fullerton' 'Syracuse' 'Dingman Township' 'Newburgh' 'Fontana' 'Essex'
#  'Towson' 'Muncie' 'Irving' 'Oxnard' 'Butte' 'Janesville' 'Chicopee'
#  'Cedar Hill' 'Brownsville' 'Huntington' 'Visalia' 'Glendale' 'Redding'
#  'Monterey' 'Laredo' 'North Port' 'Palm Bay' 'Iowa City' 'Olathe' 'Elgin'
#  'Chelsea' 'Odessa' 'Vallejo' 'Redwood City' 'Hialeah' 'Amesbury' 'Casper'
#  'Statesville' 'El Monte' 'Evanston' 'Del Rio' 'Scranton' 'Bowling Green'
#  'Canton' 'Quincy' 'Salinas' 'Altoona' 'Flagstaff' 'Athens'
#  'Morris Plains' 'Kenosha' 'Downey' 'Harrisonburg' 'Marietta' 'Sandy'
#  'Hayward' 'Kennewick' 'Stamford' 'Weslaco' 'Laramie' 'Springtown' 'Hilo'
#  'Indio' 'Marlborough' 'Fargo' 'Biloxi' 'Largo' 'South Whitehall Township'
#  'Leominster' 'Kaneohe' 'Sunnyvale' 'Utica' 'Tempe' 'Columbia'
#  'Georgetown' 'Overland Park' 'New Castle' 'Suisun City' 'Scottsbluff'
#  'Plano' 'Grand Island' 'Cloverdale' 'Hanford' 'Macon' 'Manteca' 'Fremont'
#  'Newton' 'Torrance' 'Mission Viejo' 'Laurel' 'Lakeland' 'Round Rock'
#  'Lower Providence Township' 'Hot Springs' 'Alexandria' 'Fairbanks'
#  'Cedar Rapids' 'Hickory' 'Valdosta' 'Independence' 'Red Bay' 'Manhattan'
#  'Dodge City' 'Cheyenne' 'Pemberton' 'Thornton' 'Abington Township'
#  'Kailua-Kona' 'Battle Creek' 'North Augusta' 'Framingham' 'Kingsport'
#  'Chesapeake' 'Joplin' 'Victorville' 'Mankato' 'South Bend' 'Norfolk'
#  'Lewisville' 'Westfield' 'Missoula' 'Fort Wayne' 'Canyon'
#  'Lower Southampton Township' 'Madera' 'Oxford' 'Bossier City' 'Racine'
#  'Wausau' 'Decatur' 'Tifton' 'New Brunswick' 'Pawtucket' 'Dothan'
#  'Mendham Township' 'Lehi' 'Hanover Township' 'Sparta' 'Turlock'
#  'Deerfield Beach' 'Killeen' 'Gulfport' 'Simi Valley' 'Ogden' 'Edinburg'
#  'Southaven' 'Johns Creek' 'Kalispell' 'Iowa Colony' 'Appleton' 'Antioch'
#  'Concord Township' 'Gilroy' 'Sioux City' 'Yakima' 'Bensalem Township'
#  'Bridgeport' 'La Crosse' 'Homestead' 'Avondale' 'Warrensburg'
#  'Conyngham Township' 'Poway' 'Moline' 'Ketchikan' 'Raymore' 'Escondido'
#  'Blue Springs' 'Ashland' 'Brandon' 'Cape Girardeau' 'Salisbury'
#  'Winchester' 'Somerset' 'Bartlesville' 'North Charleston' 'Islip'
#  'Lower Merion Township' 'St. Cloud' 'Paterson' 'Holyoke' 'Deltona'
#  'Pocatello']

# %%
print("For user_followers_count, Mean: {0}, Standard Deviation: {1}, Min: {2}, Max: {3}".format(trump_df['user_followers_count'].mean(), trump_df['user_followers_count'].std(), trump_df['user_followers_count'].min(), trump_df['user_followers_count'].max()))
# Out:
# For user_followers_count, Mean: 34395.742340923265, Standard Deviation: 285514.9816134033, Min: 0.0, Max: 13783686.0

# %%
trump_df.head()
# Out:
#              created_at      tweet_id  \
# 2   2020-10-15 00:00:02  1.316529e+18
# 4   2020-10-15 00:00:08  1.316529e+18
# 11  2020-10-15 00:00:25  1.316529e+18
# 12  2020-10-15 00:00:26  1.316529e+18
# 13  2020-10-15 00:00:31  1.316529e+18
#
#                                                 tweet  likes  retweet_count  \
# 2   #Trump: As a student I used to hear for years,...    2.0            1.0
# 4   You get a tie! And you get a tie! #Trump ‘s ra...    4.0            3.0
# 11  In 2020, #NYPost is being #censorship #CENSORE...    0.0            0.0
# 12  #Trump #PresidentTrump #Trump2020LandslideVict...    3.0            5.0
# 13  @Susan_Hutch @JoeBiden #Ukraine @RealDonaldTru...    2.0            0.0
#
#                  source       user_id  \
# 2       Twitter Web App  8.436472e+06
# 4    Twitter for iPhone  4.741380e+07
# 11   Twitter for iPhone  1.994033e+07
# 12  Twitter for Android  1.243315e+18
# 13      Twitter Web App  3.439562e+08
#
#                                             user_name user_screen_name  \
# 2                                              snarke           snarke
# 4                               Rana Abtar - رنا أبتر        Ranaabtar
# 11  Change Illinois | Biden will increase taxes by...   changeillinois
# 12                                       Ron Burgundy    Anchorman_USA
# 13                                    Sebastian White        SebWrites
#
#                                      user_description       user_join_date  \
# 2   Will mock for food! Freelance writer, blogger,...  2007-08-26 05:56:11
# 4   Washington Correspondent, Lebanese-American ,c...  2009-06-15 19:05:35
# 11  Illinois, home of Lincoln and Reagan, used to ...  2009-02-02 23:08:28
# 12  I'm kind of a Big Deal, People know me! I driv...  2020-03-26 23:14:28
# 13  Tortured, literary genius, well probably the f...  2011-07-28 10:07:32
#
#     user_followers_count        lat        long               city  \
# 2                 1185.0  45.520247 -122.674195           Portland
# 4                 5393.0  38.894992  -77.036558         Washington
# 11                1396.0  41.875562  -87.624421            Chicago
# 12                 496.0  32.717421 -117.162771          San Diego
# 13                2755.0  55.953346   -3.188375  City of Edinburgh
#
#                      country      continent                 state  \
# 2   United States of America  North America                Oregon
# 4   United States of America  North America  District of Columbia
# 11  United States of America  North America              Illinois
# 12  United States of America  North America            California
# 13            United Kingdom         Europe              Scotland
#
#                      collected_at
# 2   2020-10-21 00:00:00.746433060
# 4   2020-10-21 00:00:01.492866121
# 11  2020-10-21 00:00:04.105381834
# 12  2020-10-21 00:00:04.478598364
# 13  2020-10-21 00:00:05.225031425

# %%
trump_users_df = trump_df[['user_id', 'user_name', 'user_screen_name', 'user_description', 'user_join_date', 'user_followers_count']]

# %%
trump_users_df.head()
# Out:
#          user_id                                          user_name  \
# 2   8.436472e+06                                             snarke
# 4   4.741380e+07                              Rana Abtar - رنا أبتر
# 11  1.994033e+07  Change Illinois | Biden will increase taxes by...
# 12  1.243315e+18                                       Ron Burgundy
# 13  3.439562e+08                                    Sebastian White
#
#    user_screen_name                                   user_description  \
# 2            snarke  Will mock for food! Freelance writer, blogger,...
# 4         Ranaabtar  Washington Correspondent, Lebanese-American ,c...
# 11   changeillinois  Illinois, home of Lincoln and Reagan, used to ...
# 12    Anchorman_USA  I'm kind of a Big Deal, People know me! I driv...
# 13        SebWrites  Tortured, literary genius, well probably the f...
#
#          user_join_date  user_followers_count
# 2   2007-08-26 05:56:11                1185.0
# 4   2009-06-15 19:05:35                5393.0
# 11  2009-02-02 23:08:28                1396.0
# 12  2020-03-26 23:14:28                 496.0
# 13  2011-07-28 10:07:32                2755.0

# %%
trump_users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 213309 entries, 2 to 970912
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               213309 non-null  float64
#  1   user_name             213309 non-null  object
#  2   user_screen_name      213309 non-null  object
#  3   user_description      213309 non-null  object
#  4   user_join_date        213309 non-null  object
#  5   user_followers_count  213309 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 11.4+ MB

# %%
trump_users_df[trump_users_df.duplicated()]
# Out:
#              user_id                               user_name user_screen_name  \
# 16      3.439562e+08                         Sebastian White        SebWrites
# 22      8.436472e+06                                  snarke           snarke
# 48      8.436472e+06                                  snarke           snarke
# 72      8.436472e+06                                  snarke           snarke
# 91      1.381774e+09                                     USA  AMERICANWILDMAN
# ...              ...                                     ...              ...
# 970890  8.496398e+07                          Impacto Latino    ImpactoLatino
# 970895  4.835231e+07  Linda "I Voted for Biden" Kenney Baden      KenneyBaden
# 970896  5.008862e+08                              Ken Noble😎         knoble62
# 970910  3.578492e+08                           murdoch davis     murdochdavis
# 970911  3.135361e+08                           ActivistBowen   ActivistBowen2
#
#                                          user_description  \
# 16      Tortured, literary genius, well probably the f...
# 22      Will mock for food! Freelance writer, blogger,...
# 48      Will mock for food! Freelance writer, blogger,...
# 72      Will mock for food! Freelance writer, blogger,...
# 91      I would rather die on my feet than live on my ...
# ...                                                   ...
# 970890  Últimas noticias de Nueva York, Estados Unidos...
# 970895  TrialLawyer https://t.co/1C0kKESSUC, Played by...
# 970896  Believe in live & let live. Tweets are persona...
# 970910  I try to be pithy, not pissy. Like you I fail....
# 970911  person, web writer, dissident, son, brother, f...
#
#              user_join_date  user_followers_count
# 16      2011-07-28 10:07:32                2755.0
# 22      2007-08-26 05:56:11                1185.0
# 48      2007-08-26 05:56:11                1185.0
# 72      2007-08-26 05:56:11                1185.0
# 91      2013-04-26 12:23:10                 110.0
# ...                     ...                   ...
# 970890  2009-10-24 23:36:28                1517.0
# 970895  2009-06-18 13:41:48                3024.0
# 970896  2012-02-23 15:31:47                 453.0
# 970910  2011-08-19 00:31:25                1190.0
# 970911  2011-06-08 20:17:01                3792.0
#
# [116802 rows x 6 columns]

# %%
trump_users_df['user_id'].nunique()
# Out:
# 62111

# %%
trump_locations_df = trump_df[['lat', 'long', 'city', 'state', 'country', 'continent']]

# %%
trump_locations_df.head()
# Out:
#           lat        long               city                 state  \
# 2   45.520247 -122.674195           Portland                Oregon
# 4   38.894992  -77.036558         Washington  District of Columbia
# 11  41.875562  -87.624421            Chicago              Illinois
# 12  32.717421 -117.162771          San Diego            California
# 13  55.953346   -3.188375  City of Edinburgh              Scotland
#
#                      country      continent
# 2   United States of America  North America
# 4   United States of America  North America
# 11  United States of America  North America
# 12  United States of America  North America
# 13            United Kingdom         Europe

# %%
trump_locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 213309 entries, 2 to 970912
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        213309 non-null  float64
#  1   long       213309 non-null  float64
#  2   city       213309 non-null  object
#  3   state      213309 non-null  object
#  4   country    213309 non-null  object
#  5   continent  213309 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 11.4+ MB

# %%
trump_locations_df[['lat', 'long']].nunique()
# Out:
# lat     1957
# long    1957
# dtype: int64

# %%
trump_tweets_df = trump_df[['tweet_id', 'tweet', 'likes', 'retweet_count', 'source', 'created_at', 'collected_at', 'user_id', 'lat', 'long']]

# %%
trump_tweets_df.loc[:, "tweet_about"] = "Trump"
# Out:
# <ipython-input-124-acb5a4ae94f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump_tweets_df.loc[:, "tweet_about"] = "Trump"

# %%
trump_tweets_df = trump_tweets_df[['tweet_id', 'tweet', 'likes', 'retweet_count', 'source', 'created_at', 'collected_at', 'tweet_about', 'user_id', 'lat', 'long']]

# %%
trump_tweets_df.head()
# Out:
#         tweet_id                                              tweet  likes  \
# 2   1.316529e+18  #Trump: As a student I used to hear for years,...    2.0
# 4   1.316529e+18  You get a tie! And you get a tie! #Trump ‘s ra...    4.0
# 11  1.316529e+18  In 2020, #NYPost is being #censorship #CENSORE...    0.0
# 12  1.316529e+18  #Trump #PresidentTrump #Trump2020LandslideVict...    3.0
# 13  1.316529e+18  @Susan_Hutch @JoeBiden #Ukraine @RealDonaldTru...    2.0
#
#     retweet_count               source           created_at  \
# 2             1.0      Twitter Web App  2020-10-15 00:00:02
# 4             3.0   Twitter for iPhone  2020-10-15 00:00:08
# 11            0.0   Twitter for iPhone  2020-10-15 00:00:25
# 12            5.0  Twitter for Android  2020-10-15 00:00:26
# 13            0.0      Twitter Web App  2020-10-15 00:00:31
#
#                      collected_at tweet_about       user_id        lat  \
# 2   2020-10-21 00:00:00.746433060       Trump  8.436472e+06  45.520247
# 4   2020-10-21 00:00:01.492866121       Trump  4.741380e+07  38.894992
# 11  2020-10-21 00:00:04.105381834       Trump  1.994033e+07  41.875562
# 12  2020-10-21 00:00:04.478598364       Trump  1.243315e+18  32.717421
# 13  2020-10-21 00:00:05.225031425       Trump  3.439562e+08  55.953346
#
#           long
# 2  -122.674195
# 4   -77.036558
# 11  -87.624421
# 12 -117.162771
# 13   -3.188375

# %%
trump_tweets_df['tweet_about'].unique()
# Out:
# array(['Trump'], dtype=object)

# %%
trump_tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 213309 entries, 2 to 970912
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       213309 non-null  float64
#  1   tweet          213309 non-null  object
#  2   likes          213309 non-null  float64
#  3   retweet_count  213309 non-null  float64
#  4   source         213309 non-null  object
#  5   created_at     213309 non-null  object
#  6   collected_at   213309 non-null  object
#  7   tweet_about    213309 non-null  object
#  8   user_id        213309 non-null  float64
#  9   lat            213309 non-null  float64
#  10  long           213309 non-null  float64
# dtypes: float64(6), object(5)
# memory usage: 19.5+ MB

# %%
trump_tweets_df['tweet_id'].nunique()
# Out:
# 213099

# %% [markdown]
# # **Joe Biden Tweet Dataset**

# %%
biden_df = pd.read_csv('hashtag_joebiden.csv',lineterminator='\n')

# %%
biden_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776886 entries, 0 to 776885
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            776886 non-null  object
#  1   tweet_id              776886 non-null  float64
#  2   tweet                 776886 non-null  object
#  3   likes                 776886 non-null  float64
#  4   retweet_count         776886 non-null  float64
#  5   source                776173 non-null  object
#  6   user_id               776886 non-null  float64
#  7   user_name             776861 non-null  object
#  8   user_screen_name      776886 non-null  object
#  9   user_description      694877 non-null  object
#  10  user_join_date        776886 non-null  object
#  11  user_followers_count  776886 non-null  float64
#  12  user_location         543092 non-null  object
#  13  lat                   355293 non-null  float64
#  14  long                  355293 non-null  float64
#  15  city                  186872 non-null  object
#  16  country               353779 non-null  object
#  17  continent             353797 non-null  object
#  18  state                 260195 non-null  object
#  19  state_code            244609 non-null  object
#  20  collected_at          776886 non-null  object
# dtypes: float64(7), object(14)
# memory usage: 124.5+ MB

# %%
biden_df.describe()
# Out:
#            tweet_id          likes  retweet_count       user_id  \
# count  7.768860e+05  776886.000000  776886.000000  7.768860e+05
# mean   1.322844e+18      10.161164       2.131331  4.532033e+17
# std    2.585560e+15     390.974423      96.661527  5.573483e+17
# min    1.316529e+18       0.000000       0.000000  1.081000e+03
# 25%    1.320870e+18       0.000000       0.000000  2.257285e+08
# 50%    1.323899e+18       0.000000       0.000000  2.464208e+09
# 75%    1.325115e+18       2.000000       0.000000  1.088044e+18
# max    1.325589e+18  165702.000000   63473.000000  1.325575e+18
#
#        user_followers_count            lat           long
# count          7.768860e+05  355293.000000  355293.000000
# mean           2.884994e+04      35.104203     -41.979660
# std            4.141085e+05      17.907910      67.823724
# min            0.000000e+00     -79.406307    -172.120051
# 25%            7.400000e+01      31.816038     -97.268406
# 50%            4.280000e+02      39.783730     -74.006015
# 75%            2.081000e+03      43.653482       5.966069
# max            8.241710e+07      90.000000     179.048837

# %%
print("For user_followers_count, Mean: {0}, Standard Deviation: {1}, Min: {2}, Max: {3}".format(biden_df['user_followers_count'].mean(), biden_df['user_followers_count'].std(), biden_df['user_followers_count'].min(), biden_df['user_followers_count'].max()))
# Out:
# For user_followers_count, Mean: 28849.941210164685, Standard Deviation: 414108.478188055, Min: 0.0, Max: 82417099.0

# %%
# drop irrelevant columns
biden_df.drop(['state_code', 'user_location'], axis=1, inplace=True)

# %%
# replace null descriptions with a static description
biden_df['user_description'].fillna("No user description", inplace=True)
# Out:
# <ipython-input-135-6165936ebd7b>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   biden_df['user_description'].fillna("No user description", inplace=True)

# %%
# replace null usernames with user screen names
biden_df['user_name'].fillna(biden_df['user_screen_name'], inplace=True)
# Out:
# <ipython-input-136-93412a773196>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   biden_df['user_name'].fillna(biden_df['user_screen_name'], inplace=True)

# %%
# replace null source values using the ffill method
biden_df['source'].fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-137-ada181cd19af>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   biden_df['source'].fillna(method='ffill', inplace=True)
# <ipython-input-137-ada181cd19af>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   biden_df['source'].fillna(method='ffill', inplace=True)

# %%
biden_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776886 entries, 0 to 776885
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            776886 non-null  object
#  1   tweet_id              776886 non-null  float64
#  2   tweet                 776886 non-null  object
#  3   likes                 776886 non-null  float64
#  4   retweet_count         776886 non-null  float64
#  5   source                776886 non-null  object
#  6   user_id               776886 non-null  float64
#  7   user_name             776886 non-null  object
#  8   user_screen_name      776886 non-null  object
#  9   user_description      776886 non-null  object
#  10  user_join_date        776886 non-null  object
#  11  user_followers_count  776886 non-null  float64
#  12  lat                   355293 non-null  float64
#  13  long                  355293 non-null  float64
#  14  city                  186872 non-null  object
#  15  country               353779 non-null  object
#  16  continent             353797 non-null  object
#  17  state                 260195 non-null  object
#  18  collected_at          776886 non-null  object
# dtypes: float64(7), object(12)
# memory usage: 112.6+ MB

# %%
biden_df.dropna(subset=['lat', 'long', 'city', 'country', 'continent', 'state'], inplace=True)

# %%
biden_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175797 entries, 6 to 776881
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            175797 non-null  object
#  1   tweet_id              175797 non-null  float64
#  2   tweet                 175797 non-null  object
#  3   likes                 175797 non-null  float64
#  4   retweet_count         175797 non-null  float64
#  5   source                175797 non-null  object
#  6   user_id               175797 non-null  float64
#  7   user_name             175797 non-null  object
#  8   user_screen_name      175797 non-null  object
#  9   user_description      175797 non-null  object
#  10  user_join_date        175797 non-null  object
#  11  user_followers_count  175797 non-null  float64
#  12  lat                   175797 non-null  float64
#  13  long                  175797 non-null  float64
#  14  city                  175797 non-null  object
#  15  country               175797 non-null  object
#  16  continent             175797 non-null  object
#  17  state                 175797 non-null  object
#  18  collected_at          175797 non-null  object
# dtypes: float64(7), object(12)
# memory usage: 26.8+ MB

# %%
biden_df.isnull().sum(axis=0)
# Out:
# created_at              0
# tweet_id                0
# tweet                   0
# likes                   0
# retweet_count           0
# source                  0
# user_id                 0
# user_name               0
# user_screen_name        0
# user_description        0
# user_join_date          0
# user_followers_count    0
# lat                     0
# long                    0
# city                    0
# country                 0
# continent               0
# state                   0
# collected_at            0
# dtype: int64

# %%
biden_users_df = biden_df[['user_id', 'user_name', 'user_screen_name', 'user_description', 'user_join_date', 'user_followers_count']]

# %%
biden_users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175797 entries, 6 to 776881
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               175797 non-null  float64
#  1   user_name             175797 non-null  object
#  2   user_screen_name      175797 non-null  object
#  3   user_description      175797 non-null  object
#  4   user_join_date        175797 non-null  object
#  5   user_followers_count  175797 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 9.4+ MB

# %%
biden_users_df[biden_users_df.duplicated()]
# Out:
#              user_id                                    user_name  \
# 171     1.262894e+18                                  Grandma Lee
# 176     1.672665e+07                               Rae Dumar🌊💙🌊💙🌊
# 200     1.262894e+18                                  Grandma Lee
# 284     1.958045e+07                                Michael Osuna
# 369     1.958045e+07                                Michael Osuna
# ...              ...                                          ...
# 776836  1.057408e+09                                PROJECT13 MAG
# 776844  1.098900e+18                               andreh.cimoins
# 776852  1.588826e+07               Democracy Freedom Human Rights
# 776860  2.182470e+09  M.B.I. Munshi (MNZGamerX - Ace Level Troll)
# 776876  3.772296e+08                                    Tim Welch
#
#        user_screen_name                                   user_description  \
# 171     AliciaM05246586  My Grandchildren are brilliant, beautiful and ...
# 176     RaeOfSunForever  🌊🌊🌊🌊🌊💋💜🎣💙🏈💚🎾♒Sister surviving in-side the Capi...
# 200     AliciaM05246586  My Grandchildren are brilliant, beautiful and ...
# 284             mlosuna                                No user description
# 369             mlosuna                                No user description
# ...                 ...                                                ...
# 776836     PROJECT13MAG  Sports | Motorsports | ET, Indie Film & Foodie...
# 776844          cimoins  ✨tatuador e ilustrador✨\n\ntattoo autoral | bl...
# 776852            biyer  Life is like a box of chocolates. You never kn...
# 776860        MBIMunshi  Barrister & Advocate of the Supreme Court of B...
# 776876        TimFWelch  transportation nerd; data geek.\nsenior lectur...
#
#              user_join_date  user_followers_count
# 171     2020-05-19 23:53:19                  42.0
# 176     2008-10-13 20:08:27                 789.0
# 200     2020-05-19 23:53:19                  42.0
# 284     2009-01-27 06:30:20                 133.0
# 369     2009-01-27 06:30:20                 133.0
# ...                     ...                   ...
# 776836  2013-01-03 10:12:09                8881.0
# 776844  2019-02-22 11:00:02                  52.0
# 776852  2008-08-18 03:40:48                  22.0
# 776860  2013-11-08 15:59:05                1464.0
# 776876  2011-09-21 07:13:23                 444.0
#
# [79885 rows x 6 columns]

# %%
biden_users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175797 entries, 6 to 776881
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               175797 non-null  float64
#  1   user_name             175797 non-null  object
#  2   user_screen_name      175797 non-null  object
#  3   user_description      175797 non-null  object
#  4   user_join_date        175797 non-null  object
#  5   user_followers_count  175797 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 9.4+ MB

# %%
biden_users_df['user_id'].nunique()
# Out:
# 68458

# %%
biden_locations_df = biden_df[['lat', 'long', 'city', 'state', 'country', 'continent']]

# %%
biden_locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175797 entries, 6 to 776881
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        175797 non-null  float64
#  1   long       175797 non-null  float64
#  2   city       175797 non-null  object
#  3   state      175797 non-null  object
#  4   country    175797 non-null  object
#  5   continent  175797 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 9.4+ MB

# %%
biden_locations_df[['lat', 'long']].nunique()
# Out:
# lat     1914
# long    1914
# dtype: int64

# %%
biden_tweets_df = biden_df[['tweet_id', 'tweet', 'likes', 'retweet_count', 'source', 'created_at', 'collected_at', 'user_id', 'lat', 'long']]

# %%
biden_tweets_df.loc[:, "tweet_about"] = "Biden"
# Out:
# <ipython-input-151-a45e7cac9545>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biden_tweets_df.loc[:, "tweet_about"] = "Biden"

# %%
biden_tweets_df = biden_tweets_df[['tweet_id', 'tweet', 'likes', 'retweet_count', 'source', 'created_at', 'collected_at', 'tweet_about', 'user_id', 'lat', 'long']]

# %%
biden_tweets_df.head()
# Out:
#         tweet_id                                              tweet  likes  \
# 6   1.316529e+18  In 2020, #NYPost is being #censorship #CENSORE...    0.0
# 17  1.316530e+18  Comments on this? "Do Democrats Understand how...    0.0
# 22  1.316530e+18  Twitter is doing everything they can to help D...    1.0
# 25  1.316530e+18  @RealJamesWoods #BidenCrimeFamily #JoeBiden #H...    0.0
# 28  1.316530e+18  #Trump #Obama #Clinton #Biden\n\n#ManWomanPers...    0.0
#
#     retweet_count               source           created_at  \
# 6             0.0   Twitter for iPhone  2020-10-15 00:00:25
# 17            0.0      Twitter Web App  2020-10-15 00:01:23
# 22            0.0   Twitter for iPhone  2020-10-15 00:01:47
# 25            0.0  Twitter for Android  2020-10-15 00:01:57
# 28            0.0   Twitter for iPhone  2020-10-15 00:02:05
#
#                      collected_at tweet_about       user_id        lat  \
# 6   2020-10-21 00:00:03.106963698       Biden  1.994033e+07  41.875562
# 17  2020-10-21 00:00:08.803063811       Biden  1.016593e+08  27.947760
# 22  2020-10-21 00:00:11.392200226       Biden  1.139962e+18  34.098003
# 25  2020-10-21 00:00:12.945682075       Biden  1.300837e+18  34.053691
# 28  2020-10-21 00:00:14.499163924       Biden  1.321631e+08  51.507322
#
#           long
# 6   -87.624421
# 17  -82.458444
# 22 -118.329523
# 25 -118.242766
# 28   -0.127647

# %%
biden_tweets_df['tweet_about'].unique()
# Out:
# array(['Biden'], dtype=object)

# %%
biden_tweets_df['tweet_id'].nunique()
# Out:
# 175463

# %% [markdown]
# # **Combining the datasets**

# %%
trump_tweets_df['tweet_id'].nunique() + biden_tweets_df['tweet_id'].nunique()
# Out:
# 388562

# %%
tweets_df = pd.concat([trump_tweets_df, biden_tweets_df])

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 389106 entries, 2 to 776881
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       389106 non-null  float64
#  1   tweet          389106 non-null  object
#  2   likes          389106 non-null  float64
#  3   retweet_count  389106 non-null  float64
#  4   source         389106 non-null  object
#  5   created_at     389106 non-null  object
#  6   collected_at   389106 non-null  object
#  7   tweet_about    389106 non-null  object
#  8   user_id        389106 non-null  float64
#  9   lat            389106 non-null  float64
#  10  long           389106 non-null  float64
# dtypes: float64(6), object(5)
# memory usage: 35.6+ MB

# %%
tweets_df.head()
# Out:
#         tweet_id                                              tweet  likes  \
# 2   1.316529e+18  #Trump: As a student I used to hear for years,...    2.0
# 4   1.316529e+18  You get a tie! And you get a tie! #Trump ‘s ra...    4.0
# 11  1.316529e+18  In 2020, #NYPost is being #censorship #CENSORE...    0.0
# 12  1.316529e+18  #Trump #PresidentTrump #Trump2020LandslideVict...    3.0
# 13  1.316529e+18  @Susan_Hutch @JoeBiden #Ukraine @RealDonaldTru...    2.0
#
#     retweet_count               source           created_at  \
# 2             1.0      Twitter Web App  2020-10-15 00:00:02
# 4             3.0   Twitter for iPhone  2020-10-15 00:00:08
# 11            0.0   Twitter for iPhone  2020-10-15 00:00:25
# 12            5.0  Twitter for Android  2020-10-15 00:00:26
# 13            0.0      Twitter Web App  2020-10-15 00:00:31
#
#                      collected_at tweet_about       user_id        lat  \
# 2   2020-10-21 00:00:00.746433060       Trump  8.436472e+06  45.520247
# 4   2020-10-21 00:00:01.492866121       Trump  4.741380e+07  38.894992
# 11  2020-10-21 00:00:04.105381834       Trump  1.994033e+07  41.875562
# 12  2020-10-21 00:00:04.478598364       Trump  1.243315e+18  32.717421
# 13  2020-10-21 00:00:05.225031425       Trump  3.439562e+08  55.953346
#
#           long
# 2  -122.674195
# 4   -77.036558
# 11  -87.624421
# 12 -117.162771
# 13   -3.188375

# %%
tweets_df.tail()
# Out:
#             tweet_id                                              tweet  \
# 776865  1.325589e+18  @FLOTUS I’m excited to have a FLOTUS whose vag...
# 776869  1.325589e+18  No puede ser lo #Panazis como siempre sacando ...
# 776871  1.325589e+18  Şu #biden geleli 1 gün oldu #maliyebakanı #ist...
# 776876  1.325589e+18  Mr. #Biden, tear down that wall (with #Mexico)...
# 776881  1.325589e+18  Stop laying @CNN !\n#Paris and #London dont gi...
#
#         likes  retweet_count               source           created_at  \
# 776865    0.0            0.0   Twitter for iPhone  2020-11-08 23:58:24
# 776869    0.0            0.0   Twitter for iPhone  2020-11-08 23:58:46
# 776871    0.0            0.0  Twitter for Android  2020-11-08 23:58:52
# 776876    1.0            0.0   Twitter for iPhone  2020-11-08 23:59:16
# 776881    0.0            0.0   Twitter for iPhone  2020-11-08 23:59:38
#
#                       collected_at tweet_about       user_id        lat  \
# 776865  2020-11-09 18:32:45.841439       Biden  5.545625e+07  38.894992
# 776869  2020-11-09 18:32:45.862885       Biden  7.406354e+17  32.501019
# 776871  2020-11-09 18:32:45.567901       Biden  1.317046e+18  38.414733
# 776876  2020-11-09 18:32:45.760347       Biden  3.772296e+08 -36.852095
# 776881  2020-11-09 18:32:45.613547       Biden  3.873620e+08  48.856697
#
#               long
# 776865  -77.036558
# 776869 -116.964663
# 776871   27.143412
# 776876  174.763180
# 776881    2.351462

# %%
# shuffle the merged dataframe
tweets_df = tweets_df.sample(frac=1)

# %%
tweets_df.head()
# Out:
#             tweet_id                                              tweet  \
# 470239  1.324272e+18  Pori dunia k muslman #JoeBiden k jeetne pr atn...
# 891633  1.325173e+18  Madem #USAElections2020’yi #BidenHarris2020 ka...
# 277875  1.322949e+18  #veterans vote for #biden #trump insults your ...
# 563250  1.323875e+18  @marie_nassar Register on Ecoin, british faste...
# 571874  1.323891e+18  #Trump and #Biden  locked in a nail-biter as r...
#
#         likes  retweet_count              source           created_at  \
# 470239    2.0            1.0  Twitter for iPhone  2020-11-05 08:47:14
# 891633    0.0            0.0     Twitter for Mac  2020-11-07 20:27:50
# 277875    0.0            0.0  Twitter for iPhone  2020-11-01 17:10:32
# 563250    2.0            1.0     Twitter Web App  2020-11-04 06:29:51
# 571874    0.0            0.0     Twitter Web App  2020-11-04 07:33:43
#
#                       collected_at tweet_about       user_id        lat  \
# 470239  2020-11-06 10:19:37.150765       Biden  9.884988e+17  24.866779
# 891633  2020-11-08 10:47:07.659263       Trump  9.255422e+07  41.009633
# 277875  2020-11-02 16:18:14.998847       Biden  3.189090e+09  34.053691
# 563250  2020-11-05 12:14:04.362037       Trump  1.181253e+18   9.064331
# 571874  2020-11-05 12:12:46.029048       Trump  1.743180e+08  25.204740
#
#               long
# 470239   67.031129
# 891633   28.965165
# 277875 -118.242766
# 563250    7.489297
# 571874   55.270707

# %%
# convert ids to integer notation
tweets_df[['tweet_id', 'likes', 'retweet_count', 'user_id']] = tweets_df[['tweet_id', 'likes', 'retweet_count', 'user_id']].astype(int)

# %%
tweets_df.head()
# Out:
#                    tweet_id  \
# 470239  1324272047086862336
# 891633  1325173135805566976
# 277875  1322949156428685312
# 563250  1323875087246831616
# 571874  1323891156435030016
#
#                                                     tweet  likes  \
# 470239  Pori dunia k muslman #JoeBiden k jeetne pr atn...      2
# 891633  Madem #USAElections2020’yi #BidenHarris2020 ka...      0
# 277875  #veterans vote for #biden #trump insults your ...      0
# 563250  @marie_nassar Register on Ecoin, british faste...      2
# 571874  #Trump and #Biden  locked in a nail-biter as r...      0
#
#         retweet_count              source           created_at  \
# 470239              1  Twitter for iPhone  2020-11-05 08:47:14
# 891633              0     Twitter for Mac  2020-11-07 20:27:50
# 277875              0  Twitter for iPhone  2020-11-01 17:10:32
# 563250              1     Twitter Web App  2020-11-04 06:29:51
# 571874              0     Twitter Web App  2020-11-04 07:33:43
#
#                       collected_at tweet_about              user_id  \
# 470239  2020-11-06 10:19:37.150765       Biden   988498819615744000
# 891633  2020-11-08 10:47:07.659263       Trump             92554217
# 277875  2020-11-02 16:18:14.998847       Biden           3189089658
# 563250  2020-11-05 12:14:04.362037       Trump  1181253417513172992
# 571874  2020-11-05 12:12:46.029048       Trump            174317961
#
#               lat        long
# 470239  24.866779   67.031129
# 891633  41.009633   28.965165
# 277875  34.053691 -118.242766
# 563250   9.064331    7.489297
# 571874  25.204740   55.270707

# %%
tweets_df['tweet_id'].nunique()
# Out:
# 336880

# %%
# drop rows having duplicate tweet_ids to enforce Primary Key constraint in tweets relation
tweets_df.drop_duplicates(subset=['tweet_id'], inplace=True)

# %%
print(tweets_df['tweet_id'].max())
print(tweets_df['user_id'].max())
print(tweets_df['tweet'].str.len().max())
# Out:
# 1325588824836235264
# 1325568705393274880
# 976

# %%
tweets_df['source'].str.len().max()
# Out:
# 32

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336880 entries, 470239 to 841372
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       336880 non-null  int64
#  1   tweet          336880 non-null  object
#  2   likes          336880 non-null  int64
#  3   retweet_count  336880 non-null  int64
#  4   source         336880 non-null  object
#  5   created_at     336880 non-null  object
#  6   collected_at   336880 non-null  object
#  7   tweet_about    336880 non-null  object
#  8   user_id        336880 non-null  int64
#  9   lat            336880 non-null  float64
#  10  long           336880 non-null  float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 30.8+ MB

# %%
users_df = pd.concat([trump_users_df, biden_users_df])

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 389106 entries, 2 to 776881
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               389106 non-null  float64
#  1   user_name             389106 non-null  object
#  2   user_screen_name      389106 non-null  object
#  3   user_description      389106 non-null  object
#  4   user_join_date        389106 non-null  object
#  5   user_followers_count  389106 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 20.8+ MB

# %%
users_df['user_id'].nunique()
# Out:
# 101858

# %%
# drop rows having duplicate user_ids to enforce Primary Key constraint in tweets relation
users_df.drop_duplicates(subset=['user_id'], inplace=True)

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101858 entries, 2 to 776871
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               101858 non-null  float64
#  1   user_name             101858 non-null  object
#  2   user_screen_name      101858 non-null  object
#  3   user_description      101858 non-null  object
#  4   user_join_date        101858 non-null  object
#  5   user_followers_count  101858 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 5.4+ MB

# %%
users_df.head()
# Out:
#          user_id                                          user_name  \
# 2   8.436472e+06                                             snarke
# 4   4.741380e+07                              Rana Abtar - رنا أبتر
# 11  1.994033e+07  Change Illinois | Biden will increase taxes by...
# 12  1.243315e+18                                       Ron Burgundy
# 13  3.439562e+08                                    Sebastian White
#
#    user_screen_name                                   user_description  \
# 2            snarke  Will mock for food! Freelance writer, blogger,...
# 4         Ranaabtar  Washington Correspondent, Lebanese-American ,c...
# 11   changeillinois  Illinois, home of Lincoln and Reagan, used to ...
# 12    Anchorman_USA  I'm kind of a Big Deal, People know me! I driv...
# 13        SebWrites  Tortured, literary genius, well probably the f...
#
#          user_join_date  user_followers_count
# 2   2007-08-26 05:56:11                1185.0
# 4   2009-06-15 19:05:35                5393.0
# 11  2009-02-02 23:08:28                1396.0
# 12  2020-03-26 23:14:28                 496.0
# 13  2011-07-28 10:07:32                2755.0

# %%
users_df[['user_id', 'user_followers_count']] = users_df[['user_id', 'user_followers_count']].astype(int)

# %%
print(users_df['user_name'].str.len().max())
print(users_df['user_screen_name'].str.len().max())
print(users_df['user_description'].str.len().max())
# Out:
# 50
# 15
# 225

# %%
users_df.head()
# Out:
#                 user_id                                          user_name  \
# 2               8436472                                             snarke
# 4              47413798                              Rana Abtar - رنا أبتر
# 11             19940334  Change Illinois | Biden will increase taxes by...
# 12  1243315346397966336                                       Ron Burgundy
# 13            343956175                                    Sebastian White
#
#    user_screen_name                                   user_description  \
# 2            snarke  Will mock for food! Freelance writer, blogger,...
# 4         Ranaabtar  Washington Correspondent, Lebanese-American ,c...
# 11   changeillinois  Illinois, home of Lincoln and Reagan, used to ...
# 12    Anchorman_USA  I'm kind of a Big Deal, People know me! I driv...
# 13        SebWrites  Tortured, literary genius, well probably the f...
#
#          user_join_date  user_followers_count
# 2   2007-08-26 05:56:11                  1185
# 4   2009-06-15 19:05:35                  5393
# 11  2009-02-02 23:08:28                  1396
# 12  2020-03-26 23:14:28                   496
# 13  2011-07-28 10:07:32                  2755

# %%
locations_df = pd.concat([trump_locations_df, biden_locations_df])

# %%
locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 389106 entries, 2 to 776881
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        389106 non-null  float64
#  1   long       389106 non-null  float64
#  2   city       389106 non-null  object
#  3   state      389106 non-null  object
#  4   country    389106 non-null  object
#  5   continent  389106 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 20.8+ MB

# %%
locations_df[['lat', 'long']].nunique()
# Out:
# lat     2224
# long    2224
# dtype: int64

# %%
# drop rows having duplicate (lat, long) to enforce Primary Key constraint in tweets relation
locations_df.drop_duplicates(subset=['lat', 'long'], inplace=True)

# %%
print(locations_df['city'].str.len().max())
print(locations_df['state'].str.len().max())
print(locations_df['country'].str.len().max())
print(locations_df['continent'].str.len().max())
# Out:
# 42
# 43
# 24
# 13

# %%
locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2224 entries, 2 to 772205
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        2224 non-null   float64
#  1   long       2224 non-null   float64
#  2   city       2224 non-null   object
#  3   state      2224 non-null   object
#  4   country    2224 non-null   object
#  5   continent  2224 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 121.6+ KB

# %%
locations_df.head()
# Out:
#           lat        long               city                 state  \
# 2   45.520247 -122.674195           Portland                Oregon
# 4   38.894992  -77.036558         Washington  District of Columbia
# 11  41.875562  -87.624421            Chicago              Illinois
# 12  32.717421 -117.162771          San Diego            California
# 13  55.953346   -3.188375  City of Edinburgh              Scotland
#
#                      country      continent
# 2   United States of America  North America
# 4   United States of America  North America
# 11  United States of America  North America
# 12  United States of America  North America
# 13            United Kingdom         Europe

# %% [markdown]
# # **Final Relations**

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336880 entries, 470239 to 841372
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tweet_id       336880 non-null  int64
#  1   tweet          336880 non-null  object
#  2   likes          336880 non-null  int64
#  3   retweet_count  336880 non-null  int64
#  4   source         336880 non-null  object
#  5   created_at     336880 non-null  object
#  6   collected_at   336880 non-null  object
#  7   tweet_about    336880 non-null  object
#  8   user_id        336880 non-null  int64
#  9   lat            336880 non-null  float64
#  10  long           336880 non-null  float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 30.8+ MB

# %%
tweets_df.head()
# Out:
#                    tweet_id  \
# 470239  1324272047086862336
# 891633  1325173135805566976
# 277875  1322949156428685312
# 563250  1323875087246831616
# 571874  1323891156435030016
#
#                                                     tweet  likes  \
# 470239  Pori dunia k muslman #JoeBiden k jeetne pr atn...      2
# 891633  Madem #USAElections2020’yi #BidenHarris2020 ka...      0
# 277875  #veterans vote for #biden #trump insults your ...      0
# 563250  @marie_nassar Register on Ecoin, british faste...      2
# 571874  #Trump and #Biden  locked in a nail-biter as r...      0
#
#         retweet_count              source           created_at  \
# 470239              1  Twitter for iPhone  2020-11-05 08:47:14
# 891633              0     Twitter for Mac  2020-11-07 20:27:50
# 277875              0  Twitter for iPhone  2020-11-01 17:10:32
# 563250              1     Twitter Web App  2020-11-04 06:29:51
# 571874              0     Twitter Web App  2020-11-04 07:33:43
#
#                       collected_at tweet_about              user_id  \
# 470239  2020-11-06 10:19:37.150765       Biden   988498819615744000
# 891633  2020-11-08 10:47:07.659263       Trump             92554217
# 277875  2020-11-02 16:18:14.998847       Biden           3189089658
# 563250  2020-11-05 12:14:04.362037       Trump  1181253417513172992
# 571874  2020-11-05 12:12:46.029048       Trump            174317961
#
#               lat        long
# 470239  24.866779   67.031129
# 891633  41.009633   28.965165
# 277875  34.053691 -118.242766
# 563250   9.064331    7.489297
# 571874  25.204740   55.270707

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101858 entries, 2 to 776871
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               101858 non-null  int64
#  1   user_name             101858 non-null  object
#  2   user_screen_name      101858 non-null  object
#  3   user_description      101858 non-null  object
#  4   user_join_date        101858 non-null  object
#  5   user_followers_count  101858 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 5.4+ MB

# %%
users_df.head()
# Out:
#                 user_id                                          user_name  \
# 2               8436472                                             snarke
# 4              47413798                              Rana Abtar - رنا أبتر
# 11             19940334  Change Illinois | Biden will increase taxes by...
# 12  1243315346397966336                                       Ron Burgundy
# 13            343956175                                    Sebastian White
#
#    user_screen_name                                   user_description  \
# 2            snarke  Will mock for food! Freelance writer, blogger,...
# 4         Ranaabtar  Washington Correspondent, Lebanese-American ,c...
# 11   changeillinois  Illinois, home of Lincoln and Reagan, used to ...
# 12    Anchorman_USA  I'm kind of a Big Deal, People know me! I driv...
# 13        SebWrites  Tortured, literary genius, well probably the f...
#
#          user_join_date  user_followers_count
# 2   2007-08-26 05:56:11                  1185
# 4   2009-06-15 19:05:35                  5393
# 11  2009-02-02 23:08:28                  1396
# 12  2020-03-26 23:14:28                   496
# 13  2011-07-28 10:07:32                  2755

# %%
locations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2224 entries, 2 to 772205
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        2224 non-null   float64
#  1   long       2224 non-null   float64
#  2   city       2224 non-null   object
#  3   state      2224 non-null   object
#  4   country    2224 non-null   object
#  5   continent  2224 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 121.6+ KB

# %%
locations_df.head()
# Out:
#           lat        long               city                 state  \
# 2   45.520247 -122.674195           Portland                Oregon
# 4   38.894992  -77.036558         Washington  District of Columbia
# 11  41.875562  -87.624421            Chicago              Illinois
# 12  32.717421 -117.162771          San Diego            California
# 13  55.953346   -3.188375  City of Edinburgh              Scotland
#
#                      country      continent
# 2   United States of America  North America
# 4   United States of America  North America
# 11  United States of America  North America
# 12  United States of America  North America
# 13            United Kingdom         Europe

# %% [markdown]
# # **Exporting the relations**

# %%
tweets_df.to_csv('tweets.csv', index=False)

# %%
users_df.to_csv('users.csv', index=False)

# %%
locations_df.to_csv('locations.csv', index=False)
